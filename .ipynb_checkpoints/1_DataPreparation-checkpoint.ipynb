# %% [markdown]
# # Data Preparation

# %% [markdown]
# ### Selecting the Timeseries Attributes

# %%
import pandas as pd
import numpy as np
import os
import warnings
warnings.filterwarnings('ignore')

files = ['F.csv', 'Np.csv', 'P4.csv', 'P5.csv', 'P6.csv',
         'Tp.csv', 'V.csv', 'Vx.csv', 'Xl.csv', 'Xs.csv']

label_map = {
    'NSEP': 0, 'gt10': 1, 'gt30': 2, 'gt60': 3, 'gt100': 4
}

input_dir  = './dataset'
output_dir = './output'
os.makedirs(output_dir, exist_ok=True)

for filename in files:
    filepath = os.path.join(input_dir, filename)

    # All files have a header row — use header=0 for all
    df = pd.read_csv(filepath, header=0)

    # First column is the label, last 288 are the time series
    label_col       = df.iloc[:, 0].map(label_map)
    timeseries_cols = df.iloc[:, -288:].apply(
        lambda col: pd.to_numeric(col, errors='coerce'), axis=0
    )

    result = pd.concat([label_col.reset_index(drop=True),
                        timeseries_cols.reset_index(drop=True)], axis=1)
    result.columns = range(result.shape[1])

    out_path = os.path.join(output_dir, filename)
    result.to_csv(out_path, index=False, header=False, float_format='%.12g')

    ts_vals   = timeseries_cols.values.astype(float)
    nan_count = np.isnan(ts_vals).sum()
    print(f"{filename:<10}  shape={result.shape}  |  "
          f"min={np.nanmin(ts_vals):.4e}  max={np.nanmax(ts_vals):.4e}  "
          f"mean={np.nanmean(ts_vals):.4e}  |  NaNs={nan_count}")

print("\nDone!")
# Out:
# F.csv       shape=(17794, 289)  |  min=2.7000e-01  max=1.0000e+04  mean=5.1045e+02  |  NaNs=0
# Np.csv      shape=(17794, 289)  |  min=3.0000e-02  max=6.9720e+01  mean=5.8444e+00  |  NaNs=0
# P4.csv      shape=(17794, 289)  |  min=0.0000e+00  max=1.0300e+03  mean=1.0439e+00  |  NaNs=0
# P5.csv      shape=(17794, 289)  |  min=0.0000e+00  max=9.9300e+01  mean=1.0275e-01  |  NaNs=0
# P6.csv      shape=(17794, 289)  |  min=5.7900e-04  max=4.3500e+00  mean=5.5823e-03  |  NaNs=0
# Tp.csv      shape=(17794, 289)  |  min=9.2000e+02  max=7.7280e+06  mean=1.0480e+05  |  NaNs=0
# V.csv       shape=(17794, 289)  |  min=2.3540e+02  max=1.1305e+03  mean=4.4244e+02  |  NaNs=0
# Vx.csv      shape=(17794, 289)  |  min=-1.1262e+03  max=-2.3170e+02  mean=-4.4101e+02  |  NaNs=0
# Xl.csv      shape=(17794, 289)  |  min=0.0000e+00  max=1.8400e-03  mean=1.6714e-06  |  NaNs=0
# Xs.csv      shape=(17794, 289)  |  min=0.0000e+00  max=4.8100e-04  mean=1.1529e-07  |  NaNs=0
#
# Done!

# %% [markdown]
# ### Missing value analysis

# %%
import pandas as pd
import numpy as np

files = ['F.csv', 'Np.csv', 'P4.csv', 'P5.csv', 'P6.csv',
         'Tp.csv', 'V.csv', 'Vx.csv', 'Xl.csv', 'Xs.csv']

input_dir = './output'

print(f"{'File':<12} {'Rows':>7} {'Total Cells':>12} {'Missing':>10} {'Missing %':>10} {'Rows w/ Missing':>16}")
print("-" * 72)

for filename in files:
    filepath = f"{input_dir}/{filename}"
    try:
        df = pd.read_csv(filepath, header=None, low_memory=False)
        df = df.iloc[1:].reset_index(drop=True)   # drop header row
        df = df.apply(pd.to_numeric, errors='coerce')

        total_cells   = df.size
        missing_cells = df.isna().sum().sum()
        missing_pct   = 100 * missing_cells / total_cells
        rows_affected = df.isna().any(axis=1).sum()

        print(f"{filename:<12} {len(df):>7} {total_cells:>12,} {missing_cells:>10,} {missing_pct:>9.2f}% {rows_affected:>16,}")

    except FileNotFoundError:
        print(f"{filename:<12} [FILE NOT FOUND]")

print("-" * 72)
print("\nDone!")
# Out:
# File            Rows  Total Cells    Missing  Missing %  Rows w/ Missing
# ------------------------------------------------------------------------
# F.csv          17793    5,142,177          0      0.00%                0
# Np.csv         17793    5,142,177          0      0.00%                0
# P4.csv         17793    5,142,177          0      0.00%                0
# P5.csv         17793    5,142,177          0      0.00%                0
# P6.csv         17793    5,142,177          0      0.00%                0
# Tp.csv         17793    5,142,177          0      0.00%                0
# V.csv          17793    5,142,177          0      0.00%                0
# Vx.csv         17793    5,142,177          0      0.00%                0
# Xl.csv         17793    5,142,177          0      0.00%                0
# Xs.csv         17793    5,142,177          0      0.00%                0
# ------------------------------------------------------------------------
#
# Done!

# %% [markdown]
# ### tSNE plots of classes

# %%
import warnings
warnings.filterwarnings('ignore')

import sys
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.manifold import TSNE

files = ['F.csv', 'Np.csv', 'P4.csv', 'P5.csv', 'P6.csv',
         'Tp.csv', 'V.csv', 'Vx.csv', 'Xl.csv', 'Xs.csv']

input_dir  = './output'
output_dir = './tsne_plots'
os.makedirs(output_dir, exist_ok=True)

label_names  = {0: 'NSEP', 1: 'gt10', 2: 'gt30', 3: 'gt60', 4: 'gt100'}
label_colors = {
    0: '#94A3B8',
    1: '#F43F5E',
    2: '#10B981',
    3: '#F59E0B',
    4: '#8B5CF6',
}
DOT_SMALL = 8
DOT_BIG   = 50

log = []


def plot_tsne(X_2d, labels, title, filename):
    sns.set_theme(style='whitegrid', context='talk', font='DejaVu Sans')
    fig, ax = plt.subplots(figsize=(7, 5))
    fig.patch.set_facecolor('#F8FAFC')
    ax.set_facecolor('#F1F5F9')

    for label_id in sorted(label_names.keys()):
        mask = labels == label_id
        if mask.sum() == 0:
            continue
        is_nsep = label_id == 0
        ax.scatter(
            X_2d[mask, 0], X_2d[mask, 1],
            c=label_colors[label_id],
            s=DOT_SMALL if is_nsep else DOT_BIG,
            label=f"{label_names[label_id]}  (n={mask.sum():,})",
            alpha=0.4 if is_nsep else 0.9,
            edgecolors='none' if is_nsep else 'white',
            linewidths=0 if is_nsep else 0.5,
            zorder=1 if is_nsep else 2
        )

    ax.set_title(title, fontsize=15, fontweight='bold', color='#1E293B', pad=16)
    ax.set_xlabel('t-SNE Dimension 1', fontsize=11, color='#475569', labelpad=10)
    ax.set_ylabel('t-SNE Dimension 2', fontsize=11, color='#475569', labelpad=10)
    ax.tick_params(colors='#475569', labelsize=10)

    for spine in ax.spines.values():
        spine.set_color('#E2E8F0')

    ax.yaxis.grid(True, color='#CBD5E1', linewidth=0.6, linestyle='--')
    ax.xaxis.grid(True, color='#CBD5E1', linewidth=0.6, linestyle='--')

    legend = ax.legend(
        title='Class', title_fontsize=11,
        fontsize=10, loc='best',
        framealpha=0.95, edgecolor='#CBD5E1',
        facecolor='white'
    )
    legend.get_title().set_color('#1E293B')

    plt.tight_layout()
    plt.savefig(f'{output_dir}/{filename}', dpi=150,
                bbox_inches='tight', facecolor=fig.get_facecolor())
    plt.show()   # ← display inline before closing
    plt.close()
    log.append(f"  Saved → {output_dir}/{filename}")


for filename in files:
    filepath = f"{input_dir}/{filename}"
    if not os.path.exists(filepath):
        log.append(f"[SKIP] {filename} not found")
        continue

    devnull = open(os.devnull, 'w')
    old_out, old_err = sys.stdout, sys.stderr
    sys.stdout, sys.stderr = devnull, devnull

    try:
        df = pd.read_csv(filepath, header=None, low_memory=False)
        df = df.iloc[1:].reset_index(drop=True)
        df = df.apply(pd.to_numeric, errors='coerce')
        df = df.dropna()

        labels = df.iloc[:, 0].astype(int).values
        X      = df.iloc[:, 1:].values

        tsne = TSNE(n_components=2, random_state=42, perplexity=30,
                    max_iter=1000, verbose=0)
        X_2d = tsne.fit_transform(X)
    finally:
        sys.stdout, sys.stderr = old_out, old_err
        devnull.close()

    plot_tsne(
        X_2d, labels,
        title=f't-SNE — {filename.replace(".csv", "")}',
        filename=filename.replace('.csv', '_tsne.png')
    )
    log.append(f"[DONE] {filename}")

log.append("\nAll done!")
print('\n'.join(log))
# Out:
#   Saved → ./tsne_plots/F_tsne.png
# [DONE] F.csv
#   Saved → ./tsne_plots/Np_tsne.png
# [DONE] Np.csv
#   Saved → ./tsne_plots/P4_tsne.png
# [DONE] P4.csv
#   Saved → ./tsne_plots/P5_tsne.png
# [DONE] P5.csv
#   Saved → ./tsne_plots/P6_tsne.png
# [DONE] P6.csv
#   Saved → ./tsne_plots/Tp_tsne.png
# [DONE] Tp.csv
#   Saved → ./tsne_plots/V_tsne.png
# [DONE] V.csv
#   Saved → ./tsne_plots/Vx_tsne.png
# [DONE] Vx.csv
#   Saved → ./tsne_plots/Xl_tsne.png
# [DONE] Xl.csv
#   Saved → ./tsne_plots/Xs_tsne.png
# [DONE] Xs.csv
#
# All done!

# %% [markdown]
# ### Combining files to create an MVTS

# %%
import pandas as pd
import numpy as np
import pickle
import os

files = ['F.csv', 'Np.csv', 'P4.csv', 'P5.csv', 'P6.csv',
         'Tp.csv', 'V.csv', 'Vx.csv', 'Xl.csv', 'Xs.csv']

input_dir  = './output'
output_dir = './mvts'
os.makedirs(output_dir, exist_ok=True)

all_X = []
all_y = []

for filename in files:
    filepath = f"{input_dir}/{filename}"
    if not os.path.exists(filepath):
        print(f"[SKIP] {filename} not found")
        continue

    print(f"Loading: {filename}")

    df = pd.read_csv(filepath, header=None, low_memory=False)
    df = df.apply(pd.to_numeric, errors='coerce')
    df = df.dropna()

    labels = df.iloc[:, 0].astype(int).values   # (num_samples,)
    ts     = df.iloc[:, 1:].values               # (num_samples, 288)

    all_X.append(ts)
    all_y.append(labels)

    print(f"  Samples: {len(labels)}  |  Timesteps: {ts.shape[1]}")

# Stack all files
# Each file = one feature → shape becomes (num_samples, num_timesteps, num_features)
X = np.stack(all_X, axis=-1)   # (num_samples, 288, 10)
y = all_y[0]                    # labels are the same across all files

print(f"\nFinal dataset shape : {X.shape}  →  (samples, timesteps, features)")
print(f"Labels shape        : {y.shape}")
print(f"Label distribution  : {dict(zip(*np.unique(y, return_counts=True)))}")

# Save X as pickle
pickle_path = os.path.join(output_dir, 'X.pkl')
with open(pickle_path, 'wb') as f:
    pickle.dump(X, f)
print(f"\nSaved X → {pickle_path}")

# Save y as 1D csv
labels_path = os.path.join(output_dir, 'y.csv')
pd.Series(y).to_csv(labels_path, index=False, header=False)
print(f"Saved y → {labels_path}")

print("\nAll done!")
# Out:
# Loading: F.csv
#   Samples: 17794  |  Timesteps: 288
# Loading: Np.csv
#   Samples: 17794  |  Timesteps: 288
# Loading: P4.csv
#   Samples: 17794  |  Timesteps: 288
# Loading: P5.csv
#   Samples: 17794  |  Timesteps: 288
# Loading: P6.csv
#   Samples: 17794  |  Timesteps: 288
# Loading: Tp.csv
#   Samples: 17794  |  Timesteps: 288
# Loading: V.csv
#   Samples: 17794  |  Timesteps: 288
# Loading: Vx.csv
#   Samples: 17794  |  Timesteps: 288
# Loading: Xl.csv
#   Samples: 17794  |  Timesteps: 288
# Loading: Xs.csv
#   Samples: 17794  |  Timesteps: 288
#
# Final dataset shape : (17794, 288, 10)  →  (samples, timesteps, features)
# Labels shape        : (17794,)
# Label distribution  : {0: 17625, 1: 85, 2: 27, 3: 19, 4: 38}
#
# Saved X → ./mvts/X.pkl
# Saved y → ./mvts/y.csv
#
# All done!

# %% [markdown]
# ### tSNE plots of classes using MVTS

# %%
import warnings
warnings.filterwarnings('ignore')

import os
import contextlib
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

input_dir  = './mvts'
output_dir = './plots'
os.makedirs(output_dir, exist_ok=True)

# Load data
with open(f'{input_dir}/X.pkl', 'rb') as f:
    X = pickle.load(f)
y = pd.read_csv(f'{input_dir}/y.csv', header=None).values.flatten().astype(int)

X_flat = X.reshape(X.shape[0], -1)

label_names  = {0: 'NSEP', 1: 'gt10', 2: 'gt30', 3: 'gt60', 4: 'gt100'}
label_colors = {
    0: '#94A3B8',
    1: '#F43F5E',
    2: '#10B981',
    3: '#F59E0B',
    4: '#8B5CF6',
}
DOT_SMALL = 8
DOT_BIG   = 50


def plot_embedding(X_2d, y, title, filename, xlabel, ylabel):
    sns.set_theme(style='whitegrid', context='talk', font='DejaVu Sans')
    fig, ax = plt.subplots(figsize=(7, 5))
    fig.patch.set_facecolor('#F8FAFC')
    ax.set_facecolor('#F1F5F9')

    for label_id in sorted(label_names.keys()):
        mask = y == label_id
        if mask.sum() == 0:
            continue
        is_nsep = label_id == 0
        ax.scatter(
            X_2d[mask, 0], X_2d[mask, 1],
            c=label_colors[label_id],
            s=DOT_SMALL if is_nsep else DOT_BIG,
            label=f"{label_names[label_id]}  (n={mask.sum():,})",
            alpha=0.4 if is_nsep else 0.9,
            edgecolors='none' if is_nsep else 'white',
            linewidths=0 if is_nsep else 0.5,
            zorder=1 if is_nsep else 2
        )

    ax.set_title(title, fontsize=14, fontweight='bold', color='#1E293B', pad=16)
    ax.set_xlabel(xlabel, fontsize=11, color='#475569', labelpad=10)
    ax.set_ylabel(ylabel, fontsize=11, color='#475569', labelpad=10)
    ax.tick_params(colors='#475569', labelsize=10)

    for spine in ax.spines.values():
        spine.set_color('#E2E8F0')

    ax.yaxis.grid(True, color='#CBD5E1', linewidth=0.6, linestyle='--')
    ax.xaxis.grid(True, color='#CBD5E1', linewidth=0.6, linestyle='--')

    legend = ax.legend(
        title='Class', title_fontsize=11,
        fontsize=10, loc='best',
        framealpha=0.95, edgecolor='#CBD5E1',
        facecolor='white'
    )
    legend.get_title().set_color('#1E293B')

    plt.tight_layout()
    plt.savefig(f'{output_dir}/{filename}', dpi=150,
                bbox_inches='tight', facecolor=fig.get_facecolor())
    plt.show()   # ← display inline
    plt.close()


def silence(func, *args, **kwargs):
    with open(os.devnull, 'w') as devnull:
        with contextlib.redirect_stdout(devnull), contextlib.redirect_stderr(devnull):
            return func(*args, **kwargs)


# ── PCA ───────────────────────────────────────────────────────────────────────
pca   = PCA(n_components=2, random_state=42)
X_pca = silence(pca.fit_transform, X_flat)
var   = pca.explained_variance_ratio_ * 100

plot_embedding(
    X_pca, y,
    title=f'PCA — MVTS Dataset  (PC1={var[0]:.1f}%  PC2={var[1]:.1f}%)',
    filename='pca.png',
    xlabel=f'PC1  ({var[0]:.1f}% variance)',
    ylabel=f'PC2  ({var[1]:.1f}% variance)'
)

# ── t-SNE ─────────────────────────────────────────────────────────────────────
pca50   = PCA(n_components=50, random_state=42)
X_pca50 = silence(pca50.fit_transform, X_flat)

tsne   = TSNE(n_components=2, random_state=42, perplexity=30,
              max_iter=1000, verbose=0)
X_tsne = silence(tsne.fit_transform, X_pca50)

plot_embedding(
    X_tsne, y,
    title='t-SNE — MVTS Dataset',
    filename='tsne.png',
    xlabel='t-SNE Dimension 1',
    ylabel='t-SNE Dimension 2'
)

# %% [markdown]
# ### Class Distribution

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patheffects as pe
import os

input_dir  = './mvts'
output_dir = './plots'
os.makedirs(output_dir, exist_ok=True)

y = pd.read_csv(f'{input_dir}/y.csv', header=None).values.flatten().astype(int)

label_names  = {0: 'NSEP', 1: 'gt10', 2: 'gt30', 3: 'gt60', 4: 'gt100'}
label_colors = {
    0: '#94A3B8',
    1: '#F43F5E',
    2: '#10B981',
    3: '#F59E0B',
    4: '#8B5CF6',
}

unique, counts = np.unique(y, return_counts=True)
total = counts.sum()

df_plot = pd.DataFrame({
    'Class'  : [label_names[i] for i in unique],
    'Samples': counts,
    'Color'  : [label_colors[i] for i in unique]
})

sns.set_theme(style='whitegrid', context='talk', font='DejaVu Sans')
fig, ax = plt.subplots(figsize=(8, 5))
fig.patch.set_facecolor('#F8FAFC')
ax.set_facecolor('#F1F5F9')

sns.barplot(
    data=df_plot,
    x='Class', y='Samples',
    palette=df_plot['Color'].tolist(),
    edgecolor='white', linewidth=1.5,
    ax=ax, width=0.55
)

for bar, label_id in zip(ax.patches, unique):
    cx = bar.get_x() + bar.get_width() / 2
    for alpha, extra_w in [(0.10, 0.30), (0.05, 0.55)]:
        ax.bar(cx, bar.get_height(),
               width=bar.get_width() + extra_w,
               color=label_colors[label_id],
               alpha=alpha, zorder=0, edgecolor='none')

for bar, count, label_id in zip(ax.patches, counts, unique):
    pct = 100 * count / total
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height() + total * 0.004,
        f'{count:,}',
        ha='center', va='bottom',
        fontsize=13, fontweight='bold',
        color=label_colors[label_id],
    )
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height() + total * 0.004 + counts.max() * 0.09,
        f'{pct:.1f}%',
        ha='center', va='bottom',
        fontsize=10, color='#64748B',
    )

ax.yaxis.grid(True, color='#CBD5E1', linewidth=0.8, linestyle='--')
ax.set_axisbelow(True)
for spine in ax.spines.values():
    spine.set_color('#E2E8F0')

ax.set_title('Class Distribution', fontsize=16, fontweight='bold',
             color='#1E293B', pad=20)
ax.set_xlabel('Class', fontsize=12, color='#475569', labelpad=12)
ax.set_ylabel('Number of Samples', fontsize=12, color='#475569', labelpad=12)
ax.tick_params(colors='#475569', labelsize=11)
ax.set_ylim(0, counts.max() * 1.22)

ax.text(0.99, 0.97, f'Total  {total:,} samples',
        transform=ax.transAxes, ha='right', va='top',
        fontsize=11, color='#475569', fontstyle='italic',
        bbox=dict(boxstyle='round,pad=0.5', facecolor='white',
                  edgecolor='#CBD5E1', linewidth=1.2))

plt.tight_layout()
plt.savefig(f'{output_dir}/class_distribution.png', dpi=150,
            bbox_inches='tight', facecolor=fig.get_facecolor())
plt.show()   # ← display inline
plt.close()

# %% [markdown]
# ### Zscore Normalization

# %%
import pickle
import numpy as np

with open('./mvts/X.pkl', 'rb') as f:
    X = pickle.load(f)

print("Feature 8 (Xl):")
print(f"  min={X[:,:,8].min():.4e}  max={X[:,:,8].max():.4e}  mean={X[:,:,8].mean():.4e}")
print(f"  all zeros? {(X[:,:,8] == 0).all()}")
print(f"  sample values: {X[0,:5,8]}")

print("\nFeature 9 (Xs):")
print(f"  min={X[:,:,9].min():.4e}  max={X[:,:,9].max():.4e}  mean={X[:,:,9].mean():.4e}")
print(f"  all zeros? {(X[:,:,9] == 0).all()}")
print(f"  sample values: {X[0,:5,9]}")
# Out:
# Feature 8 (Xl):
#   min=0.0000e+00  max=1.8400e-03  mean=1.6714e-06
#   all zeros? False
#   sample values: [1.23e-07 1.23e-07 1.26e-07 1.24e-07 1.26e-07]
#
# Feature 9 (Xs):
#   min=0.0000e+00  max=4.8100e-04  mean=1.1529e-07
#   all zeros? False
#   sample values: [9.20e-10 9.20e-10 9.40e-10 9.29e-10 9.25e-10]

# %%
import numpy as np
import pandas as pd
import pickle
import os

mvts_dir     = './mvts'
out_per_file = './mvts_zscore_per_file'
out_per_row  = './mvts_zscore_per_row'
os.makedirs(out_per_file, exist_ok=True)
os.makedirs(out_per_row,  exist_ok=True)

with open(os.path.join(mvts_dir, 'X.pkl'), 'rb') as f:
    X = pickle.load(f)                        # (17794, 288, 10)
y = pd.read_csv(os.path.join(mvts_dir, 'y.csv'), header=None).values.flatten()

# ── 1. Z-score per file (per feature) ────────────────────────────────────────
X_pf      = X.copy().astype(float)
feat_mean = X_pf.mean(axis=(0, 1))            # (10,)
feat_std  = X_pf.std(axis=(0, 1))             # (10,)
feat_std  = np.where(feat_std == 0, 1, feat_std)
X_pf      = (X_pf - feat_mean) / feat_std

with open(os.path.join(out_per_file, 'X.pkl'), 'wb') as f:
    pickle.dump(X_pf, f)
pd.Series(y).to_csv(os.path.join(out_per_file, 'y.csv'), index=False, header=False)

print(f"[Per-file] Done — X.pkl {X_pf.shape}  saved to '{out_per_file}/'")
print(f"           {'Feature':<10} {'Mean':>14} {'Std':>14}")
print(f"           {'-'*40}")
for i, (m, s) in enumerate(zip(feat_mean, feat_std)):
    print(f"           Feature {i:<3} {m:>14.4e} {s:>14.4e}")

# ── 2. Z-score per row (per sample per feature) ───────────────────────────────
X_pr     = X.copy().astype(float)
row_mean = X_pr.mean(axis=1, keepdims=True)   # (17794, 1, 10)
row_std  = X_pr.std(axis=1,  keepdims=True)   # (17794, 1, 10)
row_std  = np.where(row_std == 0, 1, row_std)
X_pr     = (X_pr - row_mean) / row_std

with open(os.path.join(out_per_row, 'X.pkl'), 'wb') as f:
    pickle.dump(X_pr, f)
pd.Series(y).to_csv(os.path.join(out_per_row, 'y.csv'), index=False, header=False)

print(f"\n[Per-row]  Done — X.pkl {X_pr.shape}  saved to '{out_per_row}/'")
print(f"           per-sample per-feature normalization (axis=1 over 288 timesteps)")

print("\nAll done!")
# Out:
# [Per-file] Done — X.pkl (17794, 288, 10)  saved to './mvts_zscore_per_file/'
#            Feature              Mean            Std
#            ----------------------------------------
#            Feature 0       5.1045e+02     2.1862e+03
#            Feature 1       5.8444e+00     5.1624e+00
#            Feature 2       1.0439e+00     1.9390e+01
#            Feature 3       1.0275e-01     1.9452e+00
#            Feature 4       5.5823e-03     4.7561e-02
#            Feature 5       1.0480e+05     1.1224e+05
#            Feature 6       4.4244e+02     1.0543e+02
#            Feature 7      -4.4101e+02     1.0506e+02
#            Feature 8       1.6714e-06     7.4040e-06
#            Feature 9       1.1529e-07     2.0088e-06
#
# [Per-row]  Done — X.pkl (17794, 288, 10)  saved to './mvts_zscore_per_row/'
#            per-sample per-feature normalization (axis=1 over 288 timesteps)
#
# All done!

# %%
with open('./mvts_zscore_per_file/X.pkl', 'rb') as f:
    X_pf = pickle.load(f)

print("Post-normalization check (per-file):")
print(f"{'Feature':<10} {'Mean':>12} {'Std':>12}")
print("-" * 36)
for i in range(X_pf.shape[2]):
    m = X_pf[:,:,i].mean()
    s = X_pf[:,:,i].std()
    print(f"Feature {i:<3} {m:>12.4e} {s:>12.4e}")
# Out:
# Post-normalization check (per-file):
# Feature            Mean          Std
# ------------------------------------
# Feature 0     1.3083e-13   1.0000e+00
# Feature 1    -1.0641e-14   1.0000e+00
# Feature 2    -7.9876e-13   1.0000e+00
# Feature 3    -9.2079e-14   1.0000e+00
# Feature 4    -9.0924e-13   1.0000e+00
# Feature 5     4.6844e-15   1.0000e+00
# Feature 6    -2.6724e-14   1.0000e+00
# Feature 7    -8.3324e-15   1.0000e+00
# Feature 8     4.3350e-13   1.0000e+00
# Feature 9     2.0480e-13   1.0000e+00

# %% [markdown]
# ### Custom Normalization

# %%
import numpy as np
import pandas as pd
import pickle
import os

mvts_dir   = './mvts'
out_hybrid = './mvts_hybrid_norm'
os.makedirs(out_hybrid, exist_ok=True)

with open(os.path.join(mvts_dir, 'X.pkl'), 'rb') as f:
    X = pickle.load(f)
y = pd.read_csv(os.path.join(mvts_dir, 'y.csv'), header=None).values.flatten()

X_hyb = X.copy().astype(float)   # (17794, 288, 10)

LOG_ZSCORE_FEATURES = [0, 1, 2, 3, 4, 8, 9]
ROBUST_FEATURES     = [5]
ZSCORE_FEATURES     = [6, 7]

feature_names = ['F', 'Np', 'P4', 'P5', 'P6', 'Tp', 'V', 'Vx', 'Xl', 'Xs']

print(f"{'Feature':<12} {'Method':<15} {'Mean/Med':>14} {'Std/IQR':>14}")
print(f"{'-'*57}")

for i in range(X_hyb.shape[2]):
    col = X_hyb[:, :, i]   # (17794, 288)

    if i in LOG_ZSCORE_FEATURES:
        col          = np.sign(col) * np.log1p(np.abs(col))
        mean         = col.mean()
        std          = col.std()
        std          = std if std != 0 else 1
        col          = (col - mean) / std
        method       = 'Log + Z-score'
        stat1, stat2 = mean, std

    elif i in ROBUST_FEATURES:
        flat         = col.flatten()
        median       = np.median(flat)
        q1           = np.percentile(flat, 25)
        q3           = np.percentile(flat, 75)
        iqr          = q3 - q1 if (q3 - q1) != 0 else 1
        col          = (col - median) / iqr
        method       = 'Robust'
        stat1, stat2 = median, iqr

    elif i in ZSCORE_FEATURES:
        mean         = col.mean()
        std          = col.std()
        std          = std if std != 0 else 1
        col          = (col - mean) / std
        method       = 'Z-score'
        stat1, stat2 = mean, std

    X_hyb[:, :, i] = col
    print(f"Feature {i} {feature_names[i]:<5} {method:<15} {stat1:>14.4e} {stat2:>14.4e}")

with open(os.path.join(out_hybrid, 'X.pkl'), 'wb') as f:
    pickle.dump(X_hyb, f)
pd.Series(y).to_csv(os.path.join(out_hybrid, 'y.csv'), index=False, header=False)

print(f"\n[Hybrid] Done — X.pkl {X_hyb.shape}  saved to '{out_hybrid}/'")

# ── Post-normalization sanity check ───────────────────────────
print("\nPost-normalization check:")
print(f"{'Feature':<12} {'Mean':>12} {'Std':>12}")
print(f"{'-'*38}")
for i in range(X_hyb.shape[2]):
    m = X_hyb[:, :, i].mean()
    s = X_hyb[:, :, i].std()
    print(f"Feature {i} {feature_names[i]:<5} {m:>12.4e} {s:>12.4e}")

print("\nAll done!")
# Out:
# Feature      Method                Mean/Med        Std/IQR
# ---------------------------------------------------------
# Feature 0 F     Log + Z-score       2.3371e+00     1.6275e+00
# Feature 1 Np    Log + Z-score       1.7393e+00     5.7555e-01
# Feature 2 P4    Log + Z-score       8.8941e-02     4.2334e-01
# Feature 3 P5    Log + Z-score       2.8547e-02     1.8550e-01
# Feature 4 P6    Log + Z-score       4.9956e-03     2.8954e-02
# Feature 5 Tp    Robust              7.4844e+04     9.8000e+04
# Feature 6 V     Z-score             4.4244e+02     1.0543e+02
# Feature 7 Vx    Z-score            -4.4101e+02     1.0506e+02
# Feature 8 Xl    Log + Z-score       1.6713e-06     7.4017e-06
# Feature 9 Xs    Log + Z-score       1.1528e-07     2.0086e-06
#
# [Hybrid] Done — X.pkl (17794, 288, 10)  saved to './mvts_hybrid_norm/'
#
# Post-normalization check:
# Feature              Mean          Std
# --------------------------------------
# Feature 0 F      -1.7754e-15   1.0000e+00
# Feature 1 Np      3.1029e-15   1.0000e+00
# Feature 2 P4     -8.4300e-18   1.0000e+00
# Feature 3 P5     -2.0997e-16   1.0000e+00
# Feature 4 P6      1.2137e-16   1.0000e+00
# Feature 5 Tp      3.0570e-01   1.1453e+00
# Feature 6 V       3.0676e-16   1.0000e+00
# Feature 7 Vx     -7.8799e-15   1.0000e+00
# Feature 8 Xl      2.1674e-17   1.0000e+00
# Feature 9 Xs      7.9381e-17   1.0000e+00
#
# All done!

# %% [markdown]
# ### Multiclass to Binary

# %%
import pandas as pd
import numpy as np
import pickle
import os
from collections import Counter

variants = [
    ('./mvts',                './mvts_binary'),
    ('./mvts_zscore_per_file', './mvts_zscore_per_file_binary'),
    ('./mvts_zscore_per_row',  './mvts_zscore_per_row_binary'),
    ('./mvts_hybrid_norm',     './mvts_hybrid_norm_binary'),
]

for input_dir, output_dir in variants:
    print(f"\n{'='*55}")
    print(f"Input  : {input_dir}")
    print(f"Output : {output_dir}")
    print('='*55)

    os.makedirs(output_dir, exist_ok=True)

    with open(f'{input_dir}/X.pkl', 'rb') as f:
        X = pickle.load(f)
    y = pd.read_csv(f'{input_dir}/y.csv', header=None).values.flatten().astype(int)

    print(f"Original Distribution : {Counter(y)}")

    y_binary = np.where(y > 0, 1, 0)
    print(f"Binary Distribution   : {Counter(y_binary)}")

    with open(f'{output_dir}/X.pkl', 'wb') as f:
        pickle.dump(X, f)
    pd.Series(y_binary).to_csv(f'{output_dir}/y.csv', index=False, header=False)

    print(f"Saved X → {output_dir}/X.pkl")
    print(f"Saved y → {output_dir}/y.csv")

print("\nAll done!")
# Out:
# =======================================================
# Input  : ./mvts
# Output : ./mvts_binary
# =======================================================
# Original Distribution : Counter({0: 17625, 1: 85, 4: 38, 2: 27, 3: 19})
# Binary Distribution   : Counter({0: 17625, 1: 169})
# Saved X → ./mvts_binary/X.pkl
# Saved y → ./mvts_binary/y.csv
#
# =======================================================
# Input  : ./mvts_zscore_per_file
# Output : ./mvts_zscore_per_file_binary
# =======================================================
# Original Distribution : Counter({0: 17625, 1: 85, 4: 38, 2: 27, 3: 19})
# Binary Distribution   : Counter({0: 17625, 1: 169})
# Saved X → ./mvts_zscore_per_file_binary/X.pkl
# Saved y → ./mvts_zscore_per_file_binary/y.csv
#
# =======================================================
# Input  : ./mvts_zscore_per_row
# Output : ./mvts_zscore_per_row_binary
# =======================================================
# Original Distribution : Counter({0: 17625, 1: 85, 4: 38, 2: 27, 3: 19})
# Binary Distribution   : Counter({0: 17625, 1: 169})
# Saved X → ./mvts_zscore_per_row_binary/X.pkl
# Saved y → ./mvts_zscore_per_row_binary/y.csv
#
# =======================================================
# Input  : ./mvts_hybrid_norm
# Output : ./mvts_hybrid_norm_binary
# =======================================================
# Original Distribution : Counter({0: 17625, 1: 85, 4: 38, 2: 27, 3: 19})
# Binary Distribution   : Counter({0: 17625, 1: 169})
# Saved X → ./mvts_hybrid_norm_binary/X.pkl
# Saved y → ./mvts_hybrid_norm_binary/y.csv
#
# All done!

# %% [markdown]
# ### Separate the classes

# %%
import numpy as np
import pickle
import pandas as pd
import os
from collections import Counter

variants = [
    './mvts_binary',
    './mvts_zscore_per_file_binary',
    './mvts_zscore_per_row_binary',
    './mvts_hybrid_norm_binary',
]

for input_dir in variants:
    print(f"\n{'='*55}")
    print(f"Input : {input_dir}")
    print('='*55)

    with open(f'{input_dir}/X.pkl', 'rb') as f:
        X = pickle.load(f)
    y = pd.read_csv(f'{input_dir}/y.csv', header=None).values.flatten().astype(int)

    print(f"Full Dataset Distribution : {Counter(y)}")

    nsep_idx = np.where(y == 0)[0]
    sep_idx  = np.where(y == 1)[0]

    X_nsep = X[nsep_idx];  y_nsep = y[nsep_idx]
    X_sep  = X[sep_idx];   y_sep  = y[sep_idx]

    print(f"NSEP (Class 0) Samples    : {X_nsep.shape[0]:,}")
    print(f"SEP  (Class 1) Samples    : {X_sep.shape[0]:,}")

    with open(f'{input_dir}/X_nsep.pkl', 'wb') as f:
        pickle.dump(X_nsep, f)
    with open(f'{input_dir}/X_sep.pkl', 'wb') as f:
        pickle.dump(X_sep, f)
    pd.Series(y_nsep).to_csv(f'{input_dir}/y_nsep.csv', index=False, header=False)
    pd.Series(y_sep).to_csv(f'{input_dir}/y_sep.csv',   index=False, header=False)

    print(f"Saved X_nsep, X_sep, y_nsep, y_sep → {input_dir}/")

print("\nAll done!")
# Out:
# =======================================================
# Input : ./mvts_binary
# =======================================================
# Full Dataset Distribution : Counter({0: 17625, 1: 169})
# NSEP (Class 0) Samples    : 17,625
# SEP  (Class 1) Samples    : 169
# Saved X_nsep, X_sep, y_nsep, y_sep → ./mvts_binary/
#
# =======================================================
# Input : ./mvts_zscore_per_file_binary
# =======================================================
# Full Dataset Distribution : Counter({0: 17625, 1: 169})
# NSEP (Class 0) Samples    : 17,625
# SEP  (Class 1) Samples    : 169
# Saved X_nsep, X_sep, y_nsep, y_sep → ./mvts_zscore_per_file_binary/
#
# =======================================================
# Input : ./mvts_zscore_per_row_binary
# =======================================================
# Full Dataset Distribution : Counter({0: 17625, 1: 169})
# NSEP (Class 0) Samples    : 17,625
# SEP  (Class 1) Samples    : 169
# Saved X_nsep, X_sep, y_nsep, y_sep → ./mvts_zscore_per_row_binary/
#
# =======================================================
# Input : ./mvts_hybrid_norm_binary
# =======================================================
# Full Dataset Distribution : Counter({0: 17625, 1: 169})
# NSEP (Class 0) Samples    : 17,625
# SEP  (Class 1) Samples    : 169
# Saved X_nsep, X_sep, y_nsep, y_sep → ./mvts_hybrid_norm_binary/
#
# All done!

# %% [markdown]
# ### Train-test split (70 - 10 - 20) and shuffling

# %%
import numpy as np
import pandas as pd
import pickle
import os
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

variants = [
    ('./mvts_binary',                './final_split_data_noNorm'),
    ('./mvts_zscore_per_row_binary',  './final_split_data_RowNorm'),
    ('./mvts_zscore_per_file_binary', './final_split_data_FileNorm'),
    ('./mvts_hybrid_norm_binary',     './final_split_data_HybridNorm'),
]

def save_bundle(X_data, y_data, filepath):
    with open(filepath, 'wb') as f:
        pickle.dump({'X': X_data, 'y': y_data}, f)
    print(f"Saved : {filepath}")

for input_dir, output_dir in variants:
    print(f"\n{'='*55}")
    print(f"Input  : {input_dir}")
    print(f"Output : {output_dir}")
    print('='*55)

    os.makedirs(output_dir, exist_ok=True)

    with open(f'{input_dir}/X_nsep.pkl', 'rb') as f:
        X_nsep = pickle.load(f)
    with open(f'{input_dir}/X_sep.pkl', 'rb') as f:
        X_sep = pickle.load(f)

    y_nsep = pd.read_csv(f'{input_dir}/y_nsep.csv', header=None).values.flatten().astype(int)
    y_sep  = pd.read_csv(f'{input_dir}/y_sep.csv',  header=None).values.flatten().astype(int)

    print(f"NSEP samples : {X_nsep.shape[0]:,}")
    print(f"SEP  samples : {X_sep.shape[0]:,}")

    # ── Step 1: Split NSEP 70-10-20 ──────────────────────────────────────────
    X_nsep_tv, X_nsep_test, y_nsep_tv, y_nsep_test = train_test_split(
        X_nsep, y_nsep, test_size=0.20, random_state=42, shuffle=False)

    X_nsep_train, X_nsep_val, y_nsep_train, y_nsep_val = train_test_split(
        X_nsep_tv, y_nsep_tv, test_size=0.125, random_state=42, shuffle=False)

    # ── Step 2: Split SEP 70-10-20 ───────────────────────────────────────────
    X_sep_tv, X_sep_test, y_sep_tv, y_sep_test = train_test_split(
        X_sep, y_sep, test_size=0.20, random_state=42, shuffle=False)

    X_sep_train, X_sep_val, y_sep_train, y_sep_val = train_test_split(
        X_sep_tv, y_sep_tv, test_size=0.125, random_state=42, shuffle=False)

    # ── Step 3: Combine ───────────────────────────────────────────────────────
    X_train = np.concatenate([X_nsep_train, X_sep_train], axis=0)
    y_train = np.concatenate([y_nsep_train, y_sep_train], axis=0)

    X_val   = np.concatenate([X_nsep_val,   X_sep_val],   axis=0)
    y_val   = np.concatenate([y_nsep_val,   y_sep_val],   axis=0)

    X_test  = np.concatenate([X_nsep_test,  X_sep_test],  axis=0)
    y_test  = np.concatenate([y_nsep_test,  y_sep_test],  axis=0)

    # ── Step 4: Shuffle ───────────────────────────────────────────────────────
    X_train, y_train = shuffle(X_train, y_train, random_state=42)
    X_val,   y_val   = shuffle(X_val,   y_val,   random_state=42)
    X_test,  y_test  = shuffle(X_test,  y_test,  random_state=42)

    print(f"\nTrain : {X_train.shape[0]:,} samples  |  {Counter(y_train)}")
    print(f"Val   : {X_val.shape[0]:,}   samples  |  {Counter(y_val)}")
    print(f"Test  : {X_test.shape[0]:,}  samples  |  {Counter(y_test)}")

    # ── Step 5: Save ─────────────────────────────────────────────────────────
    save_bundle(X_train, y_train, os.path.join(output_dir, 'train_set.pkl'))
    save_bundle(X_val,   y_val,   os.path.join(output_dir, 'val_set.pkl'))
    save_bundle(X_test,  y_test,  os.path.join(output_dir, 'test_set.pkl'))

    del X_nsep, X_sep, X_train, X_val, X_test

print("\nAll done!")
# Out:
# =======================================================
# Input  : ./mvts_binary
# Output : ./final_split_data_noNorm
# =======================================================
# NSEP samples : 17,625
# SEP  samples : 169
#
# Train : 12,455 samples  |  Counter({0: 12337, 1: 118})
# Val   : 1,780   samples  |  Counter({0: 1763, 1: 17})
# Test  : 3,559  samples  |  Counter({0: 3525, 1: 34})
# Saved : ./final_split_data_noNorm/train_set.pkl
# Saved : ./final_split_data_noNorm/val_set.pkl
# Saved : ./final_split_data_noNorm/test_set.pkl
#
# =======================================================
# Input  : ./mvts_zscore_per_row_binary
# Output : ./final_split_data_RowNorm
# =======================================================
# NSEP samples : 17,625
# SEP  samples : 169
#
# Train : 12,455 samples  |  Counter({0: 12337, 1: 118})
# Val   : 1,780   samples  |  Counter({0: 1763, 1: 17})
# Test  : 3,559  samples  |  Counter({0: 3525, 1: 34})
# Saved : ./final_split_data_RowNorm/train_set.pkl
# Saved : ./final_split_data_RowNorm/val_set.pkl
# Saved : ./final_split_data_RowNorm/test_set.pkl
#
# =======================================================
# Input  : ./mvts_zscore_per_file_binary
# Output : ./final_split_data_FileNorm
# =======================================================
# NSEP samples : 17,625
# SEP  samples : 169
#
# Train : 12,455 samples  |  Counter({0: 12337, 1: 118})
# Val   : 1,780   samples  |  Counter({0: 1763, 1: 17})
# Test  : 3,559  samples  |  Counter({0: 3525, 1: 34})
# Saved : ./final_split_data_FileNorm/train_set.pkl
# Saved : ./final_split_data_FileNorm/val_set.pkl
# Saved : ./final_split_data_FileNorm/test_set.pkl
#
# =======================================================
# Input  : ./mvts_hybrid_norm_binary
# Output : ./final_split_data_HybridNorm
# =======================================================
# NSEP samples : 17,625
# SEP  samples : 169
#
# Train : 12,455 samples  |  Counter({0: 12337, 1: 118})
# Val   : 1,780   samples  |  Counter({0: 1763, 1: 17})
# Test  : 3,559  samples  |  Counter({0: 3525, 1: 34})
# Saved : ./final_split_data_HybridNorm/train_set.pkl
# Saved : ./final_split_data_HybridNorm/val_set.pkl
# Saved : ./final_split_data_HybridNorm/test_set.pkl
#
# All done!

# %%
import shutil
import os

# ── Intermediate folders to delete ───────────────────────────────────────────
to_delete = [
    './output',
    './mvts',
    './mvts_binary',
    './mvts_zscore_per_file',
    './mvts_zscore_per_file_binary',
    './mvts_zscore_per_row',
    './mvts_zscore_per_row_binary',
    './mvts_hybrid_norm',
    './mvts_hybrid_norm_binary'
]

for folder in to_delete:
    if os.path.exists(folder):
        shutil.rmtree(folder)
        print(f"[DELETED]  {folder}")
    else:
        print(f"[SKIP]     {folder}  (not found)")

print("\nCleanup complete!")
# Out:
# [DELETED]  ./output
# [DELETED]  ./mvts
# [DELETED]  ./mvts_binary
# [DELETED]  ./mvts_zscore_per_file
# [DELETED]  ./mvts_zscore_per_file_binary
# [DELETED]  ./mvts_zscore_per_row
# [DELETED]  ./mvts_zscore_per_row_binary
# [DELETED]  ./mvts_hybrid_norm
# [DELETED]  ./mvts_hybrid_norm_binary
#
# Cleanup complete!
