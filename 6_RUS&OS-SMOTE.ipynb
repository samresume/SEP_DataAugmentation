# %% [markdown]
# # Impacts of Over Sampling (SMOTE)

# %% [markdown]
# ### Loading data and using RUS and SMOTE

# %%
import pickle
import numpy as np
import os
import time

from imblearn.over_sampling import SMOTE

def load_split(path):
    with open(path, "rb") as f:
        data = pickle.load(f)
    return data["X"].astype(np.float32), data["y"]


# ---------------------------------------------------------
# Load saved ENN-cleaned dataset
# ---------------------------------------------------------
folder = "./final_split_data_HybridNorm_ENN"

X_train, y_train = load_split(f"{folder}/train_set.pkl")
X_val,   y_val   = load_split(f"{folder}/val_set.pkl")
X_test,  y_test  = load_split(f"{folder}/test_set.pkl")

print("Loaded ENN-cleaned dataset:")
print("Train:", X_train.shape, y_train.shape)
print("Val  :", X_val.shape,   y_val.shape)
print("Test :", X_test.shape,  y_test.shape)


# ---------------------------------------------------------
# Prepare indices
# ---------------------------------------------------------
N, T, F = X_train.shape

nonsep_idx = np.where(y_train.astype(int) == 0)[0]
sep_idx    = np.where(y_train.astype(int) == 1)[0]

original_nonsep = len(nonsep_idx)
original_sep    = len(sep_idx)

X_real_sep_all = X_train[sep_idx].astype(np.float32)
X_nonsep_all   = X_train[nonsep_idx].astype(np.float32)

print("\nOriginal ENN-cleaned training class counts:")
print("Non-SEP:", original_nonsep)
print("SEP    :", original_sep)
print(f"Ratio  : {original_nonsep / original_sep:.1f}x")
print("─" * 80)


# ---------------------------------------------------------
# Create synthetic SEP samples once using SMOTE
# Generate enough synthetic SEP for the largest target
# ---------------------------------------------------------
rng = np.random.default_rng(seed=42)

N_SYNTHETIC_SEP = max(12000, original_nonsep - original_sep)

print(f"\nSynthetic SEP samples to generate: {N_SYNTHETIC_SEP}")

X_train_flat = X_train.reshape(X_train.shape[0], T * F)

k_neighbors = min(3, original_sep - 1)

if k_neighbors < 1:
    raise ValueError(
        f"Not enough SEP samples for SMOTE. SEP count = {original_sep}"
    )

smote = SMOTE(
    sampling_strategy={1: original_sep + N_SYNTHETIC_SEP},
    k_neighbors=k_neighbors,
    random_state=42
)

# ---------------------------------------------------------
# Measure SMOTE synthetic generation time
# ---------------------------------------------------------
smote_start_time = time.time()

X_res_flat, y_res = smote.fit_resample(X_train_flat, y_train)

smote_infer_time = time.time() - smote_start_time

# SMOTE appends synthetic samples after the original samples
n_original = len(X_train_flat)

X_synthetic_flat = X_res_flat[n_original:]
y_synthetic      = y_res[n_original:]

X_synthetic_sep_all = X_synthetic_flat[y_synthetic.astype(int) == 1]
X_synthetic_sep_all = X_synthetic_sep_all.reshape(-1, T, F).astype(np.float32)

n_synthetic_generated = len(X_synthetic_sep_all)

print("\nCreated SMOTE synthetic SEP pool:")
print(f"Synthetic SEP shape          : {X_synthetic_sep_all.shape}")
print(f"Synthetic SEP count          : {n_synthetic_generated}")
print(f"SMOTE generation time        : {smote_infer_time:.4f}s")
print(f"SMOTE time per synthetic SEP : {smote_infer_time / n_synthetic_generated * 1000:.4f}ms")
print("─" * 80)


# ---------------------------------------------------------
# Save real vs synthetic SEP samples once
# ---------------------------------------------------------
SAVE_DIR = "./sep_samples"
os.makedirs(SAVE_DIR, exist_ok=True)

n_compare = min(118, len(X_real_sep_all), len(X_synthetic_sep_all))

idx_real_compare = rng.choice(
    len(X_real_sep_all),
    size=n_compare,
    replace=False
)

idx_synthetic_compare = rng.choice(
    len(X_synthetic_sep_all),
    size=n_compare,
    replace=False
)

save_path = os.path.join(SAVE_DIR, "sep_real_vs_synthetic_smote.pkl")

with open(save_path, "wb") as f:
    pickle.dump({
        "X_real_sep": X_real_sep_all[idx_real_compare],
        "y_real_sep": np.zeros(n_compare, dtype=np.int32),      # 0 = real

        "X_synthetic_sep": X_synthetic_sep_all[idx_synthetic_compare],
        "y_synthetic_sep": np.ones(n_compare, dtype=np.int32),  # 1 = synthetic

        "n_real_sep_total": original_sep,
        "n_synthetic_sep_total": len(X_synthetic_sep_all),
        "n_compare": n_compare,
        "k_neighbors": k_neighbors,
        "smote_infer_time": smote_infer_time,
        "smote_time_per_sample_ms": smote_infer_time / n_synthetic_generated * 1000,
    }, f)

print(f"Saved real vs synthetic SMOTE SEP samples → {os.path.abspath(save_path)}")
print(f"Real SEP      : {n_compare}")
print(f"Synthetic SEP : {n_compare}")
print("─" * 80)


# ---------------------------------------------------------
# Dataset configurations
# ---------------------------------------------------------
# enn_smote_balanced:
#   No RUS. Keep all Non-SEP.
#   Use synthetic SEP to make total SEP = total Non-SEP.
#
# enn_rus*_smote*:
#   RUS Non-SEP to target.
#   Use synthetic SEP to make total SEP = target.

smote_configs = {
    "enn_smote_balanced": {
        "nonsep_target": original_nonsep,
        "sep_target": original_nonsep,
        "use_rus": False,
    },

    "enn_rus8000_smote8000": {
        "nonsep_target": 8000,
        "sep_target": 8000,
        "use_rus": True,
    },

    "enn_rus4000_smote4000": {
        "nonsep_target": 4000,
        "sep_target": 4000,
        "use_rus": True,
    },

    "enn_rus2000_smote2000": {
        "nonsep_target": 2000,
        "sep_target": 2000,
        "use_rus": True,
    },

    "enn_rus1000_smote1000": {
        "nonsep_target": 1000,
        "sep_target": 1000,
        "use_rus": True,
    },

    "enn_rus500_smote500": {
        "nonsep_target": 500,
        "sep_target": 500,
        "use_rus": True,
    },
}


# ---------------------------------------------------------
# Create datasets in memory
# ---------------------------------------------------------
datasets_smote = {}

print("\nCreating ENN + SMOTE datasets:")
print(
    f"{'Dataset':<28} "
    f"{'Non-SEP':>8} "
    f"{'SEP':>8} "
    f"{'Real SEP':>10} "
    f"{'Synthetic SEP':>14} "
    f"{'RUS?':>8} "
    f"{'Shape'}"
)
print("─" * 105)

for dataset_name, cfg in smote_configs.items():

    nonsep_target = cfg["nonsep_target"]
    sep_target = cfg["sep_target"]
    use_rus = cfg["use_rus"]

    if nonsep_target > original_nonsep:
        raise ValueError(
            f"{dataset_name}: requested {nonsep_target} Non-SEP samples, "
            f"but only {original_nonsep} are available after ENN."
        )

    if sep_target < original_sep:
        raise ValueError(
            f"{dataset_name}: requested {sep_target} SEP samples, "
            f"but original SEP count is {original_sep}. "
            f"This code keeps all real SEP samples."
        )

    n_synthetic_needed = sep_target - original_sep

    if n_synthetic_needed > len(X_synthetic_sep_all):
        raise ValueError(
            f"{dataset_name}: requested {n_synthetic_needed} synthetic SEP samples, "
            f"but only {len(X_synthetic_sep_all)} are available."
        )

    # -----------------------------------------------------
    # Select Non-SEP samples
    # -----------------------------------------------------
    if use_rus:
        selected_nonsep_idx = rng.choice(
            len(X_nonsep_all),
            size=nonsep_target,
            replace=False
        )

        X_nonsep = X_nonsep_all[selected_nonsep_idx]

    else:
        X_nonsep = X_nonsep_all.copy()

    y_nonsep = np.zeros(len(X_nonsep), dtype=np.float32)

    # -----------------------------------------------------
    # Select synthetic SEP from the fixed SMOTE pool
    # -----------------------------------------------------
    selected_syn_idx = rng.choice(
        len(X_synthetic_sep_all),
        size=n_synthetic_needed,
        replace=False
    )

    X_syn_sep = X_synthetic_sep_all[selected_syn_idx]

    # Keep all real SEP + selected synthetic SEP
    X_sep = np.concatenate([X_real_sep_all, X_syn_sep], axis=0).astype(np.float32)
    y_sep = np.ones(len(X_sep), dtype=np.float32)

    # -----------------------------------------------------
    # Combine and shuffle
    # -----------------------------------------------------
    X_res = np.concatenate([X_nonsep, X_sep], axis=0).astype(np.float32)
    y_res = np.concatenate([y_nonsep, y_sep], axis=0)

    final_perm = rng.permutation(len(y_res))
    X_res = X_res[final_perm]
    y_res = y_res[final_perm]

    datasets_smote[dataset_name] = {
        "X_train": X_res,
        "y_train": y_res,

        "X_val": X_val,
        "y_val": y_val,

        "X_test": X_test,
        "y_test": y_test,

        "nonsep_target": nonsep_target,
        "sep_target": sep_target,
        "use_rus": use_rus,
        "real_sep": original_sep,
        "synthetic_sep": n_synthetic_needed,
        "smote_infer_time": smote_infer_time,
        "smote_time_per_sample_ms": smote_infer_time / n_synthetic_generated * 1000,
    }

    final_counts = np.bincount(y_res.astype(int), minlength=2)

    print(
        f"{dataset_name:<28} "
        f"{final_counts[0]:>8} "
        f"{final_counts[1]:>8} "
        f"{original_sep:>10} "
        f"{n_synthetic_needed:>14} "
        f"{str(use_rus):>8} "
        f"{X_res.shape}"
    )


print("\n✅ ENN + SMOTE datasets are ready in memory.")
print("Dictionary name: datasets_smote")
print("Datasets:")
for key in datasets_smote.keys():
    print(" ", key)

print(f"\n✅ Real vs synthetic SMOTE SEP samples saved to: {os.path.abspath(SAVE_DIR)}/")
print(f"SMOTE inference/generation time       : {smote_infer_time:.4f}s")
print(f"SMOTE time per synthetic SEP sample   : {smote_infer_time / n_synthetic_generated * 1000:.4f}ms")
# Out:
# Loaded ENN-cleaned dataset:
# Train: (12268, 288, 10) (12268,)
# Val  : (1780, 288, 10) (1780,)
# Test : (3559, 288, 10) (3559,)
#
# Original ENN-cleaned training class counts:
# Non-SEP: 12150
# SEP    : 118
# Ratio  : 103.0x
# ────────────────────────────────────────────────────────────────────────────────
#
# Synthetic SEP samples to generate: 12032
#
# Created SMOTE synthetic SEP pool:
# Synthetic SEP shape          : (12032, 288, 10)
# Synthetic SEP count          : 12032
# SMOTE generation time        : 0.2551s
# SMOTE time per synthetic SEP : 0.0212ms
# ────────────────────────────────────────────────────────────────────────────────
# Saved real vs synthetic SMOTE SEP samples → /Users/samskanderi/SEP_DataAugmentation/sep_samples/sep_real_vs_synthetic_smote.pkl
# Real SEP      : 118
# Synthetic SEP : 118
# ────────────────────────────────────────────────────────────────────────────────
#
# Creating ENN + SMOTE datasets:
# Dataset                       Non-SEP      SEP   Real SEP  Synthetic SEP     RUS? Shape
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────
# enn_smote_balanced              12150    12150        118          12032    False (24300, 288, 10)
# enn_rus8000_smote8000            8000     8000        118           7882     True (16000, 288, 10)
# enn_rus4000_smote4000            4000     4000        118           3882     True (8000, 288, 10)
# enn_rus2000_smote2000            2000     2000        118           1882     True (4000, 288, 10)
# enn_rus1000_smote1000            1000     1000        118            882     True (2000, 288, 10)
# enn_rus500_smote500               500      500        118            382     True (1000, 288, 10)
#
# ✅ ENN + SMOTE datasets are ready in memory.
# Dictionary name: datasets_smote
# Datasets:
#   enn_smote_balanced
#   enn_rus8000_smote8000
#   enn_rus4000_smote4000
#   enn_rus2000_smote2000
#   enn_rus1000_smote1000
#   enn_rus500_smote500
#
# ✅ Real vs synthetic SMOTE SEP samples saved to: /Users/samskanderi/SEP_DataAugmentation/sep_samples/
# SMOTE inference/generation time       : 0.2551s
# SMOTE time per synthetic SEP sample   : 0.0212ms

# %% [markdown]
# ### Catch22 Vectorization for SVM

# %%
import numpy as np
from joblib import Parallel, delayed
from sktime.transformations.panel.catch22 import Catch22
from sklearn.impute import SimpleImputer
import warnings

# ══════════════════════════════════════════════════════════════
# CATCH22 FEATURE EXTRACTION FOR ENN + SMOTE DATASETS
# Input : datasets_smote
#         enn_smote_balanced,
#         enn_rus8000_smote8000,
#         enn_rus4000_smote4000,
#         enn_rus2000_smote2000,
#         enn_rus1000_smote1000,
#         enn_rus500_smote500
# Output: datasets_svm_smote
# ══════════════════════════════════════════════════════════════

def _catch22_chunk(X_chunk):
    transformer = Catch22(catch24=False)
    return transformer.fit_transform(X_chunk).to_numpy()


def extract_catch22(X, label="", n_jobs=-1, chunk_size=200):

    n_samples, n_timepoints, n_channels = X.shape

    # Replace NaN / Inf before Catch22
    if not np.isfinite(X).all():
        n_bad = (~np.isfinite(X)).sum()
        print(f"    ⚠️ {n_bad} non-finite values in {label} — replacing with channel median")

        X = X.copy()

        for c in range(n_channels):
            col = X[:, :, c]
            median_c = np.nanmedian(col)

            if not np.isfinite(median_c):
                median_c = 0.0

            col[~np.isfinite(col)] = median_c
            X[:, :, c] = col

    # sktime expects shape: (samples, channels, timesteps)
    X_sktime = X.transpose(0, 2, 1).astype(np.float64)

    chunks = [
        X_sktime[i:i + chunk_size]
        for i in range(0, n_samples, chunk_size)
    ]

    print(f"    {label}: {n_samples} samples in {len(chunks)} chunks", flush=True)

    results = Parallel(n_jobs=n_jobs)(
        delayed(_catch22_chunk)(chunk)
        for chunk in chunks
    )

    X_feat = np.vstack(results)

    expected_cols = 22 * n_channels

    assert X_feat.shape == (n_samples, expected_cols), (
        f"Unexpected shape for {label}: {X_feat.shape}, "
        f"expected ({n_samples}, {expected_cols})"
    )

    return X_feat.astype(np.float32)


# ══════════════════════════════════════════════════════════════
# Sanity check before extraction
# ══════════════════════════════════════════════════════════════

print("Pre-extraction value range check:")
print(
    f"{'Dataset':<26} "
    f"{'Train shape':<22} "
    f"{'Finite?':<10} "
    f"{'Min':>12} "
    f"{'Max':>12} "
    f"{'NaN/Inf':>10} "
    f"{'Class 0':>8} "
    f"{'Class 1':>8} "
    f"{'Ratio':>8}"
)
print("─" * 130)

for dataset_name, d in datasets_smote.items():
    X = d["X_train"]
    y = d["y_train"]

    counts = np.bincount(y.astype(int), minlength=2)
    ratio = counts[0] / counts[1] if counts[1] > 0 else np.inf

    print(
        f"{dataset_name:<26} "
        f"{str(X.shape):<22} "
        f"{str(np.isfinite(X).all()):<10} "
        f"{np.nanmin(X):>12.4f} "
        f"{np.nanmax(X):>12.4f} "
        f"{(~np.isfinite(X)).sum():>10} "
        f"{counts[0]:>8} "
        f"{counts[1]:>8} "
        f"{ratio:>7.1f}x"
    )


# ══════════════════════════════════════════════════════════════
# Extract Catch22 features
# ══════════════════════════════════════════════════════════════

datasets_svm_smote = {}

print("\nExtracting Catch22 features for ENN + SMOTE datasets...")

for dataset_name, d in datasets_smote.items():

    print(f"\n[{dataset_name}] extracting train...")
    X_tr = extract_catch22(
        d["X_train"],
        label=f"{dataset_name}/train",
        n_jobs=-1,
        chunk_size=200
    )

    print(f"[{dataset_name}] extracting val...")
    X_va = extract_catch22(
        d["X_val"],
        label=f"{dataset_name}/val",
        n_jobs=-1,
        chunk_size=200
    )

    print(f"[{dataset_name}] extracting test...")
    X_te = extract_catch22(
        d["X_test"],
        label=f"{dataset_name}/test",
        n_jobs=-1,
        chunk_size=200
    )

    datasets_svm_smote[dataset_name] = {
        "X_train": X_tr,
        "y_train": d["y_train"],

        "X_val": X_va,
        "y_val": d["y_val"],

        "X_test": X_te,
        "y_test": d["y_test"],

        "nonsep_target": d.get("nonsep_target", None),
        "sep_target": d.get("sep_target", None),
        "use_rus": d.get("use_rus", None),
    }

    print(
        f"[{dataset_name}] ✓ "
        f"train {X_tr.shape} | "
        f"val {X_va.shape} | "
        f"test {X_te.shape}"
    )


# ══════════════════════════════════════════════════════════════
# Impute Catch22 features
# Fit imputer on train only, apply to val/test
# ══════════════════════════════════════════════════════════════

print("\nChecking and imputing Catch22 features...")

for dataset_name in list(datasets_svm_smote.keys()):

    d = datasets_svm_smote[dataset_name]

    X_tr = d["X_train"].copy()
    X_va = d["X_val"].copy()
    X_te = d["X_test"].copy()

    y_tr = d["y_train"]
    y_va = d["y_val"]
    y_te = d["y_test"]

    n_bad_tr = (~np.isfinite(X_tr)).sum()
    n_bad_va = (~np.isfinite(X_va)).sum()
    n_bad_te = (~np.isfinite(X_te)).sum()

    if n_bad_tr > 0 or n_bad_va > 0 or n_bad_te > 0:

        print(
            f"  ⚠️ [{dataset_name}] non-finite values — "
            f"train: {n_bad_tr}, val: {n_bad_va}, test: {n_bad_te} → imputing"
        )

        X_tr = np.where(np.isfinite(X_tr), X_tr, np.nan)
        X_va = np.where(np.isfinite(X_va), X_va, np.nan)
        X_te = np.where(np.isfinite(X_te), X_te, np.nan)

        with warnings.catch_warnings():
            warnings.simplefilter("ignore")

            imputer = SimpleImputer(strategy="median")

            X_tr = imputer.fit_transform(X_tr)
            X_va = imputer.transform(X_va)
            X_te = imputer.transform(X_te)

        X_tr = np.nan_to_num(X_tr, nan=0.0, posinf=0.0, neginf=0.0)
        X_va = np.nan_to_num(X_va, nan=0.0, posinf=0.0, neginf=0.0)
        X_te = np.nan_to_num(X_te, nan=0.0, posinf=0.0, neginf=0.0)

        print(f"  ✓ [{dataset_name}] imputed")

    else:
        print(f"  ✓ [{dataset_name}] no NaN or Inf")

    datasets_svm_smote[dataset_name] = {
        "X_train": X_tr.astype(np.float32),
        "y_train": y_tr,

        "X_val": X_va.astype(np.float32),
        "y_val": y_va,

        "X_test": X_te.astype(np.float32),
        "y_test": y_te,

        "nonsep_target": d.get("nonsep_target", None),
        "sep_target": d.get("sep_target", None),
        "use_rus": d.get("use_rus", None),
    }


# ══════════════════════════════════════════════════════════════
# Final summary
# ══════════════════════════════════════════════════════════════

print("\n✅ SVM-ready Catch22 ENN + SMOTE datasets are ready:")
print(list(datasets_svm_smote.keys()))

print(
    f"\n{'Dataset':<26} "
    f"{'Train shape':<18} "
    f"{'Val shape':<18} "
    f"{'Test shape':<18} "
    f"{'Class 0':>8} "
    f"{'Class 1':>8} "
    f"{'Ratio':>8}"
)
print("─" * 115)

for name, d in datasets_svm_smote.items():
    counts = np.bincount(d["y_train"].astype(int), minlength=2)
    ratio = counts[0] / counts[1] if counts[1] > 0 else np.inf

    print(
        f"{name:<26} "
        f"{str(d['X_train'].shape):<18} "
        f"{str(d['X_val'].shape):<18} "
        f"{str(d['X_test'].shape):<18} "
        f"{counts[0]:>8} "
        f"{counts[1]:>8} "
        f"{ratio:>7.1f}x"
    )
# Out:
# Pre-extraction value range check:
# Dataset                    Train shape            Finite?             Min          Max    NaN/Inf  Class 0  Class 1    Ratio
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# enn_smote_balanced         (24300, 288, 10)       True            -6.5136      27.8326          0    12150    12150     1.0x
# enn_rus8000_smote8000      (16000, 288, 10)       True            -6.5136      27.8326          0     8000     8000     1.0x
# enn_rus4000_smote4000      (8000, 288, 10)        True            -6.5136      27.8326          0     4000     4000     1.0x
# enn_rus2000_smote2000      (4000, 288, 10)        True            -6.5136      27.2851          0     2000     2000     1.0x
# enn_rus1000_smote1000      (2000, 288, 10)        True            -6.5136      27.2851          0     1000     1000     1.0x
# enn_rus500_smote500        (1000, 288, 10)        True            -6.5136      27.2851          0      500      500     1.0x
#
# Extracting Catch22 features for ENN + SMOTE datasets...
#
# [enn_smote_balanced] extracting train...
#     enn_smote_balanced/train: 24300 samples in 122 chunks
# [enn_smote_balanced] extracting val...
#     enn_smote_balanced/val: 1780 samples in 9 chunks
# [enn_smote_balanced] extracting test...
#     enn_smote_balanced/test: 3559 samples in 18 chunks
# [enn_smote_balanced] ✓ train (24300, 220) | val (1780, 220) | test (3559, 220)
#
# [enn_rus8000_smote8000] extracting train...
#     enn_rus8000_smote8000/train: 16000 samples in 80 chunks
# [enn_rus8000_smote8000] extracting val...
#     enn_rus8000_smote8000/val: 1780 samples in 9 chunks
# [enn_rus8000_smote8000] extracting test...
#     enn_rus8000_smote8000/test: 3559 samples in 18 chunks
# [enn_rus8000_smote8000] ✓ train (16000, 220) | val (1780, 220) | test (3559, 220)
#
# [enn_rus4000_smote4000] extracting train...
#     enn_rus4000_smote4000/train: 8000 samples in 40 chunks
# [enn_rus4000_smote4000] extracting val...
#     enn_rus4000_smote4000/val: 1780 samples in 9 chunks
# [enn_rus4000_smote4000] extracting test...
#     enn_rus4000_smote4000/test: 3559 samples in 18 chunks
# [enn_rus4000_smote4000] ✓ train (8000, 220) | val (1780, 220) | test (3559, 220)
#
# [enn_rus2000_smote2000] extracting train...
#     enn_rus2000_smote2000/train: 4000 samples in 20 chunks
# [enn_rus2000_smote2000] extracting val...
#     enn_rus2000_smote2000/val: 1780 samples in 9 chunks
# [enn_rus2000_smote2000] extracting test...
#     enn_rus2000_smote2000/test: 3559 samples in 18 chunks
# [enn_rus2000_smote2000] ✓ train (4000, 220) | val (1780, 220) | test (3559, 220)
#
# [enn_rus1000_smote1000] extracting train...
#     enn_rus1000_smote1000/train: 2000 samples in 10 chunks
# [enn_rus1000_smote1000] extracting val...
#     enn_rus1000_smote1000/val: 1780 samples in 9 chunks
# [enn_rus1000_smote1000] extracting test...
#     enn_rus1000_smote1000/test: 3559 samples in 18 chunks
# [enn_rus1000_smote1000] ✓ train (2000, 220) | val (1780, 220) | test (3559, 220)
#
# [enn_rus500_smote500] extracting train...
#     enn_rus500_smote500/train: 1000 samples in 5 chunks
# [enn_rus500_smote500] extracting val...
#     enn_rus500_smote500/val: 1780 samples in 9 chunks
# [enn_rus500_smote500] extracting test...
#     enn_rus500_smote500/test: 3559 samples in 18 chunks
# [enn_rus500_smote500] ✓ train (1000, 220) | val (1780, 220) | test (3559, 220)
#
# Checking and imputing Catch22 features...
#   ⚠️ [enn_smote_balanced] non-finite values — train: 164033, val: 18024, test: 24576 → imputing
#   ✓ [enn_smote_balanced] imputed
#   ⚠️ [enn_rus8000_smote8000] non-finite values — train: 108171, val: 18024, test: 24576 → imputing
#   ✓ [enn_rus8000_smote8000] imputed
#   ⚠️ [enn_rus4000_smote4000] non-finite values — train: 53660, val: 18024, test: 24576 → imputing
#   ✓ [enn_rus4000_smote4000] imputed
#   ⚠️ [enn_rus2000_smote2000] non-finite values — train: 26488, val: 18024, test: 24576 → imputing
#   ✓ [enn_rus2000_smote2000] imputed
#   ⚠️ [enn_rus1000_smote1000] non-finite values — train: 13236, val: 18024, test: 24576 → imputing
#   ✓ [enn_rus1000_smote1000] imputed
#   ⚠️ [enn_rus500_smote500] non-finite values — train: 6706, val: 18024, test: 24576 → imputing
#   ✓ [enn_rus500_smote500] imputed
#
# ✅ SVM-ready Catch22 ENN + SMOTE datasets are ready:
# ['enn_smote_balanced', 'enn_rus8000_smote8000', 'enn_rus4000_smote4000', 'enn_rus2000_smote2000', 'enn_rus1000_smote1000', 'enn_rus500_smote500']
#
# Dataset                    Train shape        Val shape          Test shape          Class 0  Class 1    Ratio
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# enn_smote_balanced         (24300, 220)       (1780, 220)        (3559, 220)           12150    12150     1.0x
# enn_rus8000_smote8000      (16000, 220)       (1780, 220)        (3559, 220)            8000     8000     1.0x
# enn_rus4000_smote4000      (8000, 220)        (1780, 220)        (3559, 220)            4000     4000     1.0x
# enn_rus2000_smote2000      (4000, 220)        (1780, 220)        (3559, 220)            2000     2000     1.0x
# enn_rus1000_smote1000      (2000, 220)        (1780, 220)        (3559, 220)            1000     1000     1.0x
# enn_rus500_smote500        (1000, 220)        (1780, 220)        (3559, 220)             500      500     1.0x

# %% [markdown]
# ### Classification

# %%
# ══════════════════════════════════════════════════════════════
# HELPER FUNCTIONS
# ══════════════════════════════════════════════════════════════
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.svm import SVC
import time
import os

RESULTS_DIR = "./results"
os.makedirs(RESULTS_DIR, exist_ok=True)


def compute_metrics(y_true, y_pred):
    cm             = confusion_matrix(y_true, y_pred)
    TN, FP, FN, TP = cm.ravel()

    recall    = TP / (TP + FN) if (TP + FN) > 0 else 0.0
    precision = TP / (TP + FP) if (TP + FP) > 0 else 0.0
    f1        = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0.0
    accuracy  = (TP + TN) / (TP + TN + FP + FN)

    tss  = recall - FP / (FP + TN) if (FP + TN) > 0 else 0.0

    expected = ((TP + FN) * (TP + FP) + (TN + FP) * (TN + FN)) / (TP + TN + FP + FN) ** 2
    hss1     = (accuracy - expected) / (1 - expected) if (1 - expected) > 0 else 0.0

    denom = ((TP + FN) * (FN + TN) + (TP + FP) * (FP + TN))
    hss2  = 2 * (TP * TN - FP * FN) / denom if denom > 0 else 0.0

    hits_random = (TP + FP) * (TP + FN) / (TP + TN + FP + FN)
    gss = (TP - hits_random) / (TP + FP + FN - hits_random) if (TP + FP + FN - hits_random) > 0 else 0.0

    return {
        'TP': int(TP), 'TN': int(TN), 'FP': int(FP), 'FN': int(FN),
        'tss': tss, 'hss1': hss1, 'hss2': hss2, 'gss': gss,
        'recall': recall, 'f1': f1, 'accuracy': accuracy
    }


def train_and_evaluate(model, X_train, y_train, X_test, y_test):
    t0         = time.time()
    model.fit(X_train, y_train)
    train_time = time.time() - t0

    t0         = time.time()
    y_pred     = model.predict(X_test)
    infer_time = time.time() - t0

    metrics = compute_metrics(y_test, y_pred)
    metrics['train_time'] = train_time
    metrics['infer_time'] = infer_time
    return metrics


def save_results(metrics_list, filepath):
    with open(filepath, 'w') as f:
        for m in metrics_list:
            line = (f"{m['TP']},{m['TN']},{m['FP']},{m['FN']},"
                    f"{m['tss']:.6f},{m['hss1']:.6f},{m['hss2']:.6f},{m['gss']:.6f},"
                    f"{m['recall']:.6f},{m['f1']:.6f},{m['accuracy']:.6f},"
                    f"{m['train_time']:.4f},{m['infer_time']:.4f}")
            f.write(line + "\n")


def print_results(metrics_list, title):
    keys = ['tss', 'hss1', 'hss2', 'gss', 'recall', 'f1', 'accuracy', 'train_time', 'infer_time']
    print(f"\n{'─'*55}")
    print(f"  {title}")
    print(f"{'─'*55}")
    for i, m in enumerate(metrics_list):
        print(f"  Run {i+1}: TP={m['TP']}  TN={m['TN']}  FP={m['FP']}  FN={m['FN']}")
        print(f"         TSS={m['tss']:.4f}  HSS1={m['hss1']:.4f}  HSS2={m['hss2']:.4f}  GSS={m['gss']:.4f}")
        print(f"         Recall={m['recall']:.4f}  F1={m['f1']:.4f}  Acc={m['accuracy']:.4f}")
        print(f"         Train={m['train_time']:.2f}s  Infer={m['infer_time']:.4f}s")
        print()
    print(f"  ── Average of {len(metrics_list)} runs ──")
    for k in keys:
        avg = np.mean([m[k] for m in metrics_list])
        print(f"  {k:<12} : {avg:.4f}")
    print(f"{'─'*55}")

# %% [markdown]
# ### SVM

# %%
import os
import copy
import warnings
import numpy as np

from sklearn.svm import SVC
from sklearn.exceptions import ConvergenceWarning

warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=ConvergenceWarning)

# ══════════════════════════════════════════════════════════════
# SVM FINAL EXPERIMENTS — ENN + SMOTE / RUS + SMOTE
# Uses fixed best hyperparameters selected previously
# Best model: RBF-SVC, C=0.1, gamma=scale, class_weight=balanced
#
# Input datasets:
# datasets_svm_smote
#   enn_smote_balanced
#   enn_rus8000_smote8000
#   enn_rus4000_smote4000
#   enn_rus2000_smote2000
#   enn_rus1000_smote1000
#   enn_rus500_smote500
# ══════════════════════════════════════════════════════════════

RESULTS_DIR = "./results"
os.makedirs(RESULTS_DIR, exist_ok=True)

# ---------------------------------------------------------
# Fixed best SVM hyperparameters
# ---------------------------------------------------------
best_model_class = SVC

best_params = {
    "kernel": "rbf",
    "C": 0.1,
    "gamma": "scale",
    "class_weight": "balanced",
    "cache_size": 2000
}

TARGET_VARIANTS = [
    "enn_smote_balanced",
    "enn_rus8000_smote8000",
    "enn_rus4000_smote4000",
    "enn_rus2000_smote2000",
    "enn_rus1000_smote1000",
    "enn_rus500_smote500",
]

print("═" * 70)
print("Final SVM experiments on ENN + SMOTE datasets")
print("Using fixed best hyperparameters")
print("═" * 70)
print(f"Model  : {best_model_class.__name__}")
print(f"Params : {best_params}")


# ---------------------------------------------------------
# Run final experiments on ENN + SMOTE datasets
# ---------------------------------------------------------
all_smote_svm_results = {}

for dataset_key in TARGET_VARIANTS:

    if dataset_key not in datasets_svm_smote:
        print(f"[{dataset_key}] not found — skipping")
        continue

    d = datasets_svm_smote[dataset_key]

    print("\n" + "─" * 70)
    print(f"Dataset : {dataset_key}")
    print(f"Model   : {best_model_class.__name__}")
    print(f"Params  : {best_params}")

    train_counts = np.bincount(d["y_train"].astype(int), minlength=2)
    val_counts   = np.bincount(d["y_val"].astype(int), minlength=2)
    test_counts  = np.bincount(d["y_test"].astype(int), minlength=2)

    train_ratio = train_counts[0] / train_counts[1] if train_counts[1] > 0 else np.inf

    print(f"Train shape : {d['X_train'].shape}")
    print(f"Val shape   : {d['X_val'].shape}")
    print(f"Test shape  : {d['X_test'].shape}")
    print(f"Train class : Non-SEP={train_counts[0]} | SEP={train_counts[1]} | Ratio={train_ratio:.1f}:1")
    print(f"Val class   : Non-SEP={val_counts[0]} | SEP={val_counts[1]}")
    print(f"Test class  : Non-SEP={test_counts[0]} | SEP={test_counts[1]}")
    print("─" * 70)

    metrics_list = []

    for run in range(2):

        model = best_model_class(**copy.deepcopy(best_params))

        metrics = train_and_evaluate(
            model,
            d["X_train"], d["y_train"],
            d["X_test"],  d["y_test"]
        )

        metrics_list.append(metrics)

        precision_text = (
            f" | Precision={metrics['precision']:.4f}"
            if "precision" in metrics else ""
        )

        print(
            f"Run {run + 1}: "
            f"TSS={metrics['tss']:.4f} | "
            f"F1={metrics['f1']:.4f} | "
            f"Recall={metrics['recall']:.4f}"
            f"{precision_text} | "
            f"Train={metrics['train_time']:.2f}s"
        )

    all_smote_svm_results[dataset_key] = metrics_list

    filepath = os.path.join(RESULTS_DIR, f"svm_{dataset_key}.txt")
    save_results(metrics_list, filepath)
    print_results(metrics_list, f"SVM | {dataset_key}")


# ---------------------------------------------------------
# Select best SMOTE dataset by average TSS
# ---------------------------------------------------------
best_dataset = None
best_avg_tss = -np.inf

print("\n" + "═" * 70)
print("SVM ENN + SMOTE summary")
print("═" * 70)

print(
    f"{'Dataset':<26} "
    f"{'Non-SEP':>8} "
    f"{'SEP':>8} "
    f"{'Ratio':>10} "
    f"{'Avg TSS':>10} "
    f"{'Avg F1':>10} "
    f"{'Avg Recall':>12}"
)
print("─" * 95)

for dataset_key, metrics_list in all_smote_svm_results.items():

    d = datasets_svm_smote[dataset_key]

    counts = np.bincount(d["y_train"].astype(int), minlength=2)
    ratio = counts[0] / counts[1] if counts[1] > 0 else np.inf

    avg_tss = np.mean([m["tss"] for m in metrics_list])
    avg_f1 = np.mean([m["f1"] for m in metrics_list])
    avg_recall = np.mean([m["recall"] for m in metrics_list])

    print(
        f"{dataset_key:<26} "
        f"{counts[0]:>8} "
        f"{counts[1]:>8} "
        f"{ratio:>9.1f}x "
        f"{avg_tss:>10.4f} "
        f"{avg_f1:>10.4f} "
        f"{avg_recall:>12.4f}"
    )

    if avg_tss > best_avg_tss:
        best_avg_tss = avg_tss
        best_dataset = dataset_key


print("\nBest SVM ENN + SMOTE dataset:")
print(f"  Dataset : {best_dataset}")
print(f"  Avg TSS : {best_avg_tss:.4f}")
print(f"  Model   : {best_model_class.__name__}")
print(f"  Params  : {best_params}")

print("\nAll SVM ENN + SMOTE experiments complete.")
print(f"Results saved to: {os.path.abspath(RESULTS_DIR)}/")
print(f"Files: {sorted([f for f in os.listdir(RESULTS_DIR) if f.endswith('.txt')])}")
# Out:
# ══════════════════════════════════════════════════════════════════════
# Final SVM experiments on ENN + SMOTE datasets
# Using fixed best hyperparameters
# ══════════════════════════════════════════════════════════════════════
# Model  : SVC
# Params : {'kernel': 'rbf', 'C': 0.1, 'gamma': 'scale', 'class_weight': 'balanced', 'cache_size': 2000}
#
# ──────────────────────────────────────────────────────────────────────
# Dataset : enn_smote_balanced
# Model   : SVC
# Params  : {'kernel': 'rbf', 'C': 0.1, 'gamma': 'scale', 'class_weight': 'balanced', 'cache_size': 2000}
# Train shape : (24300, 220)
# Val shape   : (1780, 220)
# Test shape  : (3559, 220)
# Train class : Non-SEP=12150 | SEP=12150 | Ratio=1.0:1
# Val class   : Non-SEP=1763 | SEP=17
# Test class  : Non-SEP=3525 | SEP=34
# ──────────────────────────────────────────────────────────────────────
# Run 1: TSS=0.4489 | F1=0.0734 | Recall=0.5882 | Train=42.84s
# Run 2: TSS=0.4489 | F1=0.0734 | Recall=0.5882 | Train=44.43s
#
# ───────────────────────────────────────────────────────
#   SVM | enn_smote_balanced
# ───────────────────────────────────────────────────────
#   Run 1: TP=20  TN=3034  FP=491  FN=14
#          TSS=0.4489  HSS1=0.0565  HSS2=0.0565  GSS=0.0291
#          Recall=0.5882  F1=0.0734  Acc=0.8581
#          Train=42.84s  Infer=5.9916s
#
#   Run 2: TP=20  TN=3034  FP=491  FN=14
#          TSS=0.4489  HSS1=0.0565  HSS2=0.0565  GSS=0.0291
#          Recall=0.5882  F1=0.0734  Acc=0.8581
#          Train=44.43s  Infer=5.6936s
#
#   ── Average of 2 runs ──
#   tss          : 0.4489
#   hss1         : 0.0565
#   hss2         : 0.0565
#   gss          : 0.0291
#   recall       : 0.5882
#   f1           : 0.0734
#   accuracy     : 0.8581
#   train_time   : 43.6336
#   infer_time   : 5.8426
# ───────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────
# Dataset : enn_rus8000_smote8000
# Model   : SVC
# Params  : {'kernel': 'rbf', 'C': 0.1, 'gamma': 'scale', 'class_weight': 'balanced', 'cache_size': 2000}
# Train shape : (16000, 220)
# Val shape   : (1780, 220)
# Test shape  : (3559, 220)
# Train class : Non-SEP=8000 | SEP=8000 | Ratio=1.0:1
# Val class   : Non-SEP=1763 | SEP=17
# Test class  : Non-SEP=3525 | SEP=34
# ──────────────────────────────────────────────────────────────────────
# Run 1: TSS=0.4538 | F1=0.0758 | Recall=0.5882 | Train=16.60s
# Run 2: TSS=0.4538 | F1=0.0758 | Recall=0.5882 | Train=16.99s
#
# ───────────────────────────────────────────────────────
#   SVM | enn_rus8000_smote8000
# ───────────────────────────────────────────────────────
#   Run 1: TP=20  TN=3051  FP=474  FN=14
#          TSS=0.4538  HSS1=0.0589  HSS2=0.0589  GSS=0.0304
#          Recall=0.5882  F1=0.0758  Acc=0.8629
#          Train=16.60s  Infer=3.8656s
#
#   Run 2: TP=20  TN=3051  FP=474  FN=14
#          TSS=0.4538  HSS1=0.0589  HSS2=0.0589  GSS=0.0304
#          Recall=0.5882  F1=0.0758  Acc=0.8629
#          Train=16.99s  Infer=3.8803s
#
#   ── Average of 2 runs ──
#   tss          : 0.4538
#   hss1         : 0.0589
#   hss2         : 0.0589
#   gss          : 0.0304
#   recall       : 0.5882
#   f1           : 0.0758
#   accuracy     : 0.8629
#   train_time   : 16.7960
#   infer_time   : 3.8730
# ───────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────
# Dataset : enn_rus4000_smote4000
# Model   : SVC
# Params  : {'kernel': 'rbf', 'C': 0.1, 'gamma': 'scale', 'class_weight': 'balanced', 'cache_size': 2000}
# Train shape : (8000, 220)
# Val shape   : (1780, 220)
# Test shape  : (3559, 220)
# Train class : Non-SEP=4000 | SEP=4000 | Ratio=1.0:1
# Val class   : Non-SEP=1763 | SEP=17
# Test class  : Non-SEP=3525 | SEP=34
# ──────────────────────────────────────────────────────────────────────
# Run 1: TSS=0.4349 | F1=0.0776 | Recall=0.5588 | Train=3.52s
# Run 2: TSS=0.4349 | F1=0.0776 | Recall=0.5588 | Train=3.41s
#
# ───────────────────────────────────────────────────────
#   SVM | enn_rus4000_smote4000
# ───────────────────────────────────────────────────────
#   Run 1: TP=19  TN=3088  FP=437  FN=15
#          TSS=0.4349  HSS1=0.0609  HSS2=0.0609  GSS=0.0314
#          Recall=0.5588  F1=0.0776  Acc=0.8730
#          Train=3.52s  Infer=2.0677s
#
#   Run 2: TP=19  TN=3088  FP=437  FN=15
#          TSS=0.4349  HSS1=0.0609  HSS2=0.0609  GSS=0.0314
#          Recall=0.5588  F1=0.0776  Acc=0.8730
#          Train=3.41s  Infer=2.0747s
#
#   ── Average of 2 runs ──
#   tss          : 0.4349
#   hss1         : 0.0609
#   hss2         : 0.0609
#   gss          : 0.0314
#   recall       : 0.5588
#   f1           : 0.0776
#   accuracy     : 0.8730
#   train_time   : 3.4674
#   infer_time   : 2.0712
# ───────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────
# Dataset : enn_rus2000_smote2000
# Model   : SVC
# Params  : {'kernel': 'rbf', 'C': 0.1, 'gamma': 'scale', 'class_weight': 'balanced', 'cache_size': 2000}
# Train shape : (4000, 220)
# Val shape   : (1780, 220)
# Test shape  : (3559, 220)
# Train class : Non-SEP=2000 | SEP=2000 | Ratio=1.0:1
# Val class   : Non-SEP=1763 | SEP=17
# Test class  : Non-SEP=3525 | SEP=34
# ──────────────────────────────────────────────────────────────────────
# Run 1: TSS=0.4425 | F1=0.0821 | Recall=0.5588 | Train=0.89s
# Run 2: TSS=0.4425 | F1=0.0821 | Recall=0.5588 | Train=0.89s
#
# ───────────────────────────────────────────────────────
#   SVM | enn_rus2000_smote2000
# ───────────────────────────────────────────────────────
#   Run 1: TP=19  TN=3115  FP=410  FN=15
#          TSS=0.4425  HSS1=0.0655  HSS2=0.0655  GSS=0.0339
#          Recall=0.5588  F1=0.0821  Acc=0.8806
#          Train=0.89s  Infer=1.1071s
#
#   Run 2: TP=19  TN=3115  FP=410  FN=15
#          TSS=0.4425  HSS1=0.0655  HSS2=0.0655  GSS=0.0339
#          Recall=0.5588  F1=0.0821  Acc=0.8806
#          Train=0.89s  Infer=1.0990s
#
#   ── Average of 2 runs ──
#   tss          : 0.4425
#   hss1         : 0.0655
#   hss2         : 0.0655
#   gss          : 0.0339
#   recall       : 0.5588
#   f1           : 0.0821
#   accuracy     : 0.8806
#   train_time   : 0.8897
#   infer_time   : 1.1030
# ───────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────
# Dataset : enn_rus1000_smote1000
# Model   : SVC
# Params  : {'kernel': 'rbf', 'C': 0.1, 'gamma': 'scale', 'class_weight': 'balanced', 'cache_size': 2000}
# Train shape : (2000, 220)
# Val shape   : (1780, 220)
# Test shape  : (3559, 220)
# Train class : Non-SEP=1000 | SEP=1000 | Ratio=1.0:1
# Val class   : Non-SEP=1763 | SEP=17
# Test class  : Non-SEP=3525 | SEP=34
# ──────────────────────────────────────────────────────────────────────
# Run 1: TSS=0.4191 | F1=0.0816 | Recall=0.5294 | Train=0.25s
# Run 2: TSS=0.4191 | F1=0.0816 | Recall=0.5294 | Train=0.24s
#
# ───────────────────────────────────────────────────────
#   SVM | enn_rus1000_smote1000
# ───────────────────────────────────────────────────────
#   Run 1: TP=18  TN=3136  FP=389  FN=16
#          TSS=0.4191  HSS1=0.0651  HSS2=0.0651  GSS=0.0337
#          Recall=0.5294  F1=0.0816  Acc=0.8862
#          Train=0.25s  Infer=0.6306s
#
#   Run 2: TP=18  TN=3136  FP=389  FN=16
#          TSS=0.4191  HSS1=0.0651  HSS2=0.0651  GSS=0.0337
#          Recall=0.5294  F1=0.0816  Acc=0.8862
#          Train=0.24s  Infer=0.6187s
#
#   ── Average of 2 runs ──
#   tss          : 0.4191
#   hss1         : 0.0651
#   hss2         : 0.0651
#   gss          : 0.0337
#   recall       : 0.5294
#   f1           : 0.0816
#   accuracy     : 0.8862
#   train_time   : 0.2457
#   infer_time   : 0.6247
# ───────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────
# Dataset : enn_rus500_smote500
# Model   : SVC
# Params  : {'kernel': 'rbf', 'C': 0.1, 'gamma': 'scale', 'class_weight': 'balanced', 'cache_size': 2000}
# Train shape : (1000, 220)
# Val shape   : (1780, 220)
# Test shape  : (3559, 220)
# Train class : Non-SEP=500 | SEP=500 | Ratio=1.0:1
# Val class   : Non-SEP=1763 | SEP=17
# Test class  : Non-SEP=3525 | SEP=34
# ──────────────────────────────────────────────────────────────────────
# Run 1: TSS=0.3487 | F1=0.0800 | Recall=0.4412 | Train=0.07s
# Run 2: TSS=0.3487 | F1=0.0800 | Recall=0.4412 | Train=0.07s
#
# ───────────────────────────────────────────────────────
#   SVM | enn_rus500_smote500
# ───────────────────────────────────────────────────────
#   Run 1: TP=15  TN=3199  FP=326  FN=19
#          TSS=0.3487  HSS1=0.0637  HSS2=0.0637  GSS=0.0329
#          Recall=0.4412  F1=0.0800  Acc=0.9031
#          Train=0.07s  Infer=0.3283s
#
#   Run 2: TP=15  TN=3199  FP=326  FN=19
#          TSS=0.3487  HSS1=0.0637  HSS2=0.0637  GSS=0.0329
#          Recall=0.4412  F1=0.0800  Acc=0.9031
#          Train=0.07s  Infer=0.3274s
#
#   ── Average of 2 runs ──
#   tss          : 0.3487
#   hss1         : 0.0637
#   hss2         : 0.0637
#   gss          : 0.0329
#   recall       : 0.4412
#   f1           : 0.0800
#   accuracy     : 0.9031
#   train_time   : 0.0658
#   infer_time   : 0.3278
# ───────────────────────────────────────────────────────
#
# ══════════════════════════════════════════════════════════════════════
# SVM ENN + SMOTE summary
# ══════════════════════════════════════════════════════════════════════
# Dataset                     Non-SEP      SEP      Ratio    Avg TSS     Avg F1   Avg Recall
# ───────────────────────────────────────────────────────────────────────────────────────────────
# enn_smote_balanced            12150    12150       1.0x     0.4489     0.0734       0.5882
# enn_rus8000_smote8000          8000     8000       1.0x     0.4538     0.0758       0.5882
# enn_rus4000_smote4000          4000     4000       1.0x     0.4349     0.0776       0.5588
# enn_rus2000_smote2000          2000     2000       1.0x     0.4425     0.0821       0.5588
# enn_rus1000_smote1000          1000     1000       1.0x     0.4191     0.0816       0.5294
# enn_rus500_smote500             500      500       1.0x     0.3487     0.0800       0.4412
#
# Best SVM ENN + SMOTE dataset:
#   Dataset : enn_rus8000_smote8000
#   Avg TSS : 0.4538
#   Model   : SVC
#   Params  : {'kernel': 'rbf', 'C': 0.1, 'gamma': 'scale', 'class_weight': 'balanced', 'cache_size': 2000}
#
# All SVM ENN + SMOTE experiments complete.
# Results saved to: /Users/samskanderi/SEP_DataAugmentation/results/
# Files: ['gru_enn_nonsep_1000.txt', 'gru_enn_nonsep_2000.txt', 'gru_enn_nonsep_4000.txt', 'gru_enn_nonsep_500.txt', 'gru_enn_nonsep_8000.txt', 'gru_enn_rus1000_smote1000.txt', 'gru_enn_rus2000_smote2000.txt', 'gru_enn_rus4000_smote4000.txt', 'gru_enn_rus500_smote500.txt', 'gru_enn_rus8000_smote8000.txt', 'gru_enn_smote_balanced.txt', 'gru_hybrid.txt', 'gru_hybrid_12h.txt', 'gru_hybrid_18h.txt', 'gru_hybrid_6h.txt', 'gru_hybrid_9h.txt', 'gru_hybrid_enn.txt', 'gru_hybrid_nearmiss.txt', 'gru_hybrid_tomek.txt', 'gru_log_all.txt', 'gru_minmax_all.txt', 'gru_zscore_all.txt', 'inceptiontime_enn_nonsep_1000.txt', 'inceptiontime_enn_nonsep_2000.txt', 'inceptiontime_enn_nonsep_4000.txt', 'inceptiontime_enn_nonsep_500.txt', 'inceptiontime_enn_nonsep_8000.txt', 'inceptiontime_enn_rus1000_smote1000.txt', 'inceptiontime_enn_rus2000_smote2000.txt', 'inceptiontime_enn_rus4000_smote4000.txt', 'inceptiontime_enn_rus500_smote500.txt', 'inceptiontime_enn_rus8000_smote8000.txt', 'inceptiontime_enn_smote_balanced.txt', 'inceptiontime_hybrid.txt', 'inceptiontime_hybrid_12h.txt', 'inceptiontime_hybrid_18h.txt', 'inceptiontime_hybrid_6h.txt', 'inceptiontime_hybrid_9h.txt', 'inceptiontime_hybrid_enn.txt', 'inceptiontime_hybrid_nearmiss.txt', 'inceptiontime_hybrid_tomek.txt', 'inceptiontime_log_all.txt', 'inceptiontime_minmax_all.txt', 'inceptiontime_zscore_all.txt', 'patchtst_enn_nonsep_1000.txt', 'patchtst_enn_nonsep_2000.txt', 'patchtst_enn_nonsep_4000.txt', 'patchtst_enn_nonsep_500.txt', 'patchtst_enn_nonsep_8000.txt', 'patchtst_enn_rus1000_smote1000.txt', 'patchtst_enn_rus2000_smote2000.txt', 'patchtst_enn_rus4000_smote4000.txt', 'patchtst_enn_rus500_smote500.txt', 'patchtst_enn_rus8000_smote8000.txt', 'patchtst_enn_smote_balanced.txt', 'patchtst_hybrid.txt', 'patchtst_hybrid_12h.txt', 'patchtst_hybrid_18h.txt', 'patchtst_hybrid_6h.txt', 'patchtst_hybrid_9h.txt', 'patchtst_hybrid_enn.txt', 'patchtst_hybrid_nearmiss.txt', 'patchtst_hybrid_tomek.txt', 'patchtst_log_all.txt', 'patchtst_minmax_all.txt', 'patchtst_zscore_all.txt', 'svm_enn_nonsep_1000.txt', 'svm_enn_nonsep_2000.txt', 'svm_enn_nonsep_4000.txt', 'svm_enn_nonsep_500.txt', 'svm_enn_nonsep_8000.txt', 'svm_enn_rus1000_smote1000.txt', 'svm_enn_rus2000_smote2000.txt', 'svm_enn_rus4000_smote4000.txt', 'svm_enn_rus500_smote500.txt', 'svm_enn_rus8000_smote8000.txt', 'svm_enn_smote_balanced.txt', 'svm_hybrid.txt', 'svm_hybrid_12h.txt', 'svm_hybrid_18h.txt', 'svm_hybrid_6h.txt', 'svm_hybrid_9h.txt', 'svm_log_all.txt', 'svm_minmax_all.txt', 'svm_zscore_all.txt']

# %% [markdown]
# ### GRU

# %%
# ══════════════════════════════════════════════════════════════
# HELPER FUNCTIONS — PyTorch
# ══════════════════════════════════════════════════════════════
import torch
import torch.nn as nn
import numpy as np
import time
import os
import warnings
warnings.filterwarnings('ignore')

device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print(f"Using device: {device}")


class GRUModel(nn.Module):
    def __init__(self, input_size, hidden_size=128, num_layers=1, dropout=0.3):
        super(GRUModel, self).__init__()
        self.gru      = nn.GRU(input_size, hidden_size, num_layers=num_layers,
                               batch_first=True,
                               dropout=dropout if num_layers > 1 else 0)
        self.bn       = nn.BatchNorm1d(hidden_size)
        self.dropout  = nn.Dropout(dropout)
        self.fc1      = nn.Linear(hidden_size, 32)
        self.relu     = nn.ReLU()
        self.dropout2 = nn.Dropout(0.2)
        self.fc2      = nn.Linear(32, 1)

    def forward(self, x):
        out, _ = self.gru(x)
        out    = out[:, -1, :]
        out    = self.bn(out)
        out    = self.dropout(out)
        out    = self.relu(self.fc1(out))
        out    = self.dropout2(out)
        return self.fc2(out).squeeze()


def train_and_evaluate_gru(params, X_train, y_train, X_val, y_val, X_test, y_test, class_ratio=13):
    X_tr = torch.tensor(X_train, dtype=torch.float32).to(device)
    y_tr = torch.tensor(y_train, dtype=torch.float32).to(device)
    X_va = torch.tensor(X_val,   dtype=torch.float32).to(device)
    y_va = torch.tensor(y_val,   dtype=torch.float32).to(device)
    X_te = torch.tensor(X_test,  dtype=torch.float32).to(device)

    input_size = X_train.shape[2]
    model      = GRUModel(input_size,
                          hidden_size = params["units"],
                          num_layers  = params["layers"],
                          dropout     = params["dropout"]).to(device)

    pos_weight = torch.tensor([float(class_ratio)], dtype=torch.float32).to(device)
    criterion  = nn.BCEWithLogitsLoss(pos_weight=pos_weight)
    optimizer  = torch.optim.Adam(model.parameters(), lr=params["lr"])

    batch_size     = params["batch_size"]
    n_samples      = X_tr.shape[0]
    best_val_loss  = float('inf')
    patience_count = 0
    best_state     = None

    t0 = time.time()
    for epoch in range(50):
        model.train()
        perm = torch.randperm(n_samples)
        for i in range(0, n_samples, batch_size):
            idx    = perm[i:i + batch_size]
            xb, yb = X_tr[idx], y_tr[idx]
            optimizer.zero_grad()
            loss   = criterion(model(xb), yb)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_loss = criterion(model(X_va), y_va).item()

        if val_loss < best_val_loss:
            best_val_loss  = val_loss
            patience_count = 0
            best_state     = {k: v.clone() for k, v in model.state_dict().items()}
        else:
            patience_count += 1
            if patience_count >= 5:
                break

    train_time = time.time() - t0

    model.load_state_dict(best_state)
    model.eval()
    t0 = time.time()
    with torch.no_grad():
        y_prob = torch.sigmoid(model(X_te)).cpu().numpy()
    y_pred     = (y_prob >= 0.5).astype(int)
    infer_time = time.time() - t0

    metrics = compute_metrics(y_test.astype(int), y_pred)
    metrics['train_time'] = train_time
    metrics['infer_time'] = infer_time
    return metrics, model
# Out:
# Using device: mps

# %%
import os
import numpy as np
import copy

# ══════════════════════════════════════════════════════════════
# GRU FINAL EXPERIMENTS — ENN + SMOTE / RUS + SMOTE
# Uses fixed best hyperparameters selected previously
# Best params: units=128, layers=1, dropout=0.3, lr=0.001, batch_size=32
# Datasets:
#   enn_smote_balanced
#   enn_rus8000_smote8000
#   enn_rus4000_smote4000
#   enn_rus2000_smote2000
#   enn_rus1000_smote1000
#   enn_rus500_smote500
# ══════════════════════════════════════════════════════════════

RESULTS_DIR = "./results"
os.makedirs(RESULTS_DIR, exist_ok=True)

# ---------------------------------------------------------
# Fixed best GRU hyperparameters
# ---------------------------------------------------------
best_params = {
    "units": 128,
    "layers": 1,
    "dropout": 0.3,
    "lr": 0.001,
    "batch_size": 32
}

TARGET_VARIANTS = [
    "enn_smote_balanced",
    "enn_rus8000_smote8000",
    "enn_rus4000_smote4000",
    "enn_rus2000_smote2000",
    "enn_rus1000_smote1000",
    "enn_rus500_smote500",
]

print(f"{'═' * 70}")
print("  Classifier : GRU (PyTorch)")
print("  Experiment : ENN + SMOTE / RUS + SMOTE")
print(f"  Best params: {best_params}")
print(f"{'═' * 70}")


# ---------------------------------------------------------
# Run final GRU experiments on SMOTE datasets
# ---------------------------------------------------------
all_gru_smote_results = {}

for dataset_key in TARGET_VARIANTS:

    if dataset_key not in datasets_smote:
        print(f"[{dataset_key}] not found — skipping")
        continue

    d = datasets_smote[dataset_key]

    timesteps = d["X_train"].shape[1]

    train_counts = np.bincount(d["y_train"].astype(int), minlength=2)
    val_counts   = np.bincount(d["y_val"].astype(int), minlength=2)
    test_counts  = np.bincount(d["y_test"].astype(int), minlength=2)

    cr = train_counts[0] / train_counts[1]

    print("\n" + "─" * 70)
    print(f"Dataset   : {dataset_key}")
    print(f"Timesteps : {timesteps}")
    print(f"Train     : {d['X_train'].shape} | Non-SEP={train_counts[0]} | SEP={train_counts[1]}")
    print(f"Val       : {d['X_val'].shape} | Non-SEP={val_counts[0]} | SEP={val_counts[1]}")
    print(f"Test      : {d['X_test'].shape} | Non-SEP={test_counts[0]} | SEP={test_counts[1]}")
    print(f"Ratio     : {cr:.1f}:1")
    print(f"Params    : {best_params}")
    print("─" * 70)

    metrics_list = []

    for run in range(2):

        print(f"Run {run + 1} …", flush=True)

        metrics, _ = train_and_evaluate_gru(
            copy.deepcopy(best_params),
            d["X_train"], d["y_train"],
            d["X_val"],   d["y_val"],
            d["X_test"],  d["y_test"],
            class_ratio=cr
        )

        metrics_list.append(metrics)

        precision_text = (
            f" | Precision={metrics['precision']:.4f}"
            if "precision" in metrics else ""
        )

        print(
            f"Run {run + 1}: "
            f"TSS={metrics['tss']:.4f} | "
            f"F1={metrics['f1']:.4f} | "
            f"Recall={metrics['recall']:.4f}"
            f"{precision_text} | "
            f"Train={metrics['train_time']:.1f}s"
        )

    all_gru_smote_results[dataset_key] = metrics_list

    filepath = os.path.join(RESULTS_DIR, f"gru_{dataset_key}.txt")
    save_results(metrics_list, filepath)
    print_results(metrics_list, f"GRU | {dataset_key}")


# ---------------------------------------------------------
# Select best SMOTE dataset by average TSS
# ---------------------------------------------------------
best_dataset = None
best_avg_tss = -np.inf

print("\n" + "═" * 70)
print("GRU ENN + SMOTE summary")
print("═" * 70)

print(
    f"{'Dataset':<26} "
    f"{'Train N':>10} "
    f"{'Non-SEP':>8} "
    f"{'SEP':>8} "
    f"{'Ratio':>10} "
    f"{'Avg TSS':>10} "
    f"{'Avg F1':>10} "
    f"{'Avg Recall':>12}"
)
print("─" * 105)

for dataset_key, metrics_list in all_gru_smote_results.items():

    d = datasets_smote[dataset_key]

    counts = np.bincount(d["y_train"].astype(int), minlength=2)
    ratio = counts[0] / counts[1]

    avg_tss = np.mean([m["tss"] for m in metrics_list])
    avg_f1 = np.mean([m["f1"] for m in metrics_list])
    avg_recall = np.mean([m["recall"] for m in metrics_list])

    print(
        f"{dataset_key:<26} "
        f"{len(d['y_train']):>10} "
        f"{counts[0]:>8} "
        f"{counts[1]:>8} "
        f"{ratio:>9.1f}x "
        f"{avg_tss:>10.4f} "
        f"{avg_f1:>10.4f} "
        f"{avg_recall:>12.4f}"
    )

    if avg_tss > best_avg_tss:
        best_avg_tss = avg_tss
        best_dataset = dataset_key


print("\nBest GRU ENN + SMOTE dataset:")
print(f"  Dataset : {best_dataset}")
print(f"  Avg TSS : {best_avg_tss:.4f}")
print(f"  Params  : {best_params}")

print("\n✅ All GRU ENN + SMOTE experiments complete.")
print(f"Results saved to: {os.path.abspath(RESULTS_DIR)}/")
print(f"Files: {sorted([f for f in os.listdir(RESULTS_DIR) if f.endswith('.txt')])}")
# Out:
# ══════════════════════════════════════════════════════════════════════
#   Classifier : GRU (PyTorch)
#   Experiment : ENN + SMOTE / RUS + SMOTE
#   Best params: {'units': 128, 'layers': 1, 'dropout': 0.3, 'lr': 0.001, 'batch_size': 32}
# ══════════════════════════════════════════════════════════════════════
#
# ──────────────────────────────────────────────────────────────────────
# Dataset   : enn_smote_balanced
# Timesteps : 288
# Train     : (24300, 288, 10) | Non-SEP=12150 | SEP=12150
# Val       : (1780, 288, 10) | Non-SEP=1763 | SEP=17
# Test      : (3559, 288, 10) | Non-SEP=3525 | SEP=34
# Ratio     : 1.0:1
# Params    : {'units': 128, 'layers': 1, 'dropout': 0.3, 'lr': 0.001, 'batch_size': 32}
# ──────────────────────────────────────────────────────────────────────
# Run 1 …
# Run 1: TSS=0.1577 | F1=0.1132 | Recall=0.1765 | Train=540.3s
# Run 2 …
# Run 2: TSS=0.1349 | F1=0.1220 | Recall=0.1471 | Train=957.1s
#
# ───────────────────────────────────────────────────────
#   GRU | enn_smote_balanced
# ───────────────────────────────────────────────────────
#   Run 1: TP=6  TN=3459  FP=66  FN=28
#          TSS=0.1577  HSS1=0.1015  HSS2=0.1015  GSS=0.0535
#          Recall=0.1765  F1=0.1132  Acc=0.9736
#          Train=540.31s  Infer=0.3916s
#
#   Run 2: TP=5  TN=3482  FP=43  FN=29
#          TSS=0.1349  HSS1=0.1120  HSS2=0.1120  GSS=0.0593
#          Recall=0.1471  F1=0.1220  Acc=0.9798
#          Train=957.09s  Infer=0.3849s
#
#   ── Average of 2 runs ──
#   tss          : 0.1463
#   hss1         : 0.1068
#   hss2         : 0.1068
#   gss          : 0.0564
#   recall       : 0.1618
#   f1           : 0.1176
#   accuracy     : 0.9767
#   train_time   : 748.7008
#   infer_time   : 0.3883
# ───────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────
# Dataset   : enn_rus8000_smote8000
# Timesteps : 288
# Train     : (16000, 288, 10) | Non-SEP=8000 | SEP=8000
# Val       : (1780, 288, 10) | Non-SEP=1763 | SEP=17
# Test      : (3559, 288, 10) | Non-SEP=3525 | SEP=34
# Ratio     : 1.0:1
# Params    : {'units': 128, 'layers': 1, 'dropout': 0.3, 'lr': 0.001, 'batch_size': 32}
# ──────────────────────────────────────────────────────────────────────
# Run 1 …
# Run 1: TSS=0.2363 | F1=0.1259 | Recall=0.2647 | Train=364.2s
# Run 2 …
# Run 2: TSS=0.1040 | F1=0.0930 | Recall=0.1176 | Train=380.8s
#
# ───────────────────────────────────────────────────────
#   GRU | enn_rus8000_smote8000
# ───────────────────────────────────────────────────────
#   Run 1: TP=9  TN=3425  FP=100  FN=25
#          TSS=0.2363  HSS1=0.1130  HSS2=0.1130  GSS=0.0599
#          Recall=0.2647  F1=0.1259  Acc=0.9649
#          Train=364.16s  Infer=0.3588s
#
#   Run 2: TP=4  TN=3477  FP=48  FN=30
#          TSS=0.1040  HSS1=0.0824  HSS2=0.0824  GSS=0.0430
#          Recall=0.1176  F1=0.0930  Acc=0.9781
#          Train=380.78s  Infer=0.3591s
#
#   ── Average of 2 runs ──
#   tss          : 0.1702
#   hss1         : 0.0977
#   hss2         : 0.0977
#   gss          : 0.0514
#   recall       : 0.1912
#   f1           : 0.1094
#   accuracy     : 0.9715
#   train_time   : 372.4695
#   infer_time   : 0.3590
# ───────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────
# Dataset   : enn_rus4000_smote4000
# Timesteps : 288
# Train     : (8000, 288, 10) | Non-SEP=4000 | SEP=4000
# Val       : (1780, 288, 10) | Non-SEP=1763 | SEP=17
# Test      : (3559, 288, 10) | Non-SEP=3525 | SEP=34
# Ratio     : 1.0:1
# Params    : {'units': 128, 'layers': 1, 'dropout': 0.3, 'lr': 0.001, 'batch_size': 32}
# ──────────────────────────────────────────────────────────────────────
# Run 1 …
# Run 1: TSS=0.2369 | F1=0.1277 | Recall=0.2647 | Train=240.6s
# Run 2 …
# Run 2: TSS=0.4515 | F1=0.1532 | Recall=0.5000 | Train=205.3s
#
# ───────────────────────────────────────────────────────
#   GRU | enn_rus4000_smote4000
# ───────────────────────────────────────────────────────
#   Run 1: TP=9  TN=3427  FP=98  FN=25
#          TSS=0.2369  HSS1=0.1148  HSS2=0.1148  GSS=0.0609
#          Recall=0.2647  F1=0.1277  Acc=0.9654
#          Train=240.57s  Infer=0.3646s
#
#   Run 2: TP=17  TN=3354  FP=171  FN=17
#          TSS=0.4515  HSS1=0.1392  HSS2=0.1392  GSS=0.0748
#          Recall=0.5000  F1=0.1532  Acc=0.9472
#          Train=205.28s  Infer=0.3726s
#
#   ── Average of 2 runs ──
#   tss          : 0.3442
#   hss1         : 0.1270
#   hss2         : 0.1270
#   gss          : 0.0679
#   recall       : 0.3824
#   f1           : 0.1404
#   accuracy     : 0.9563
#   train_time   : 222.9267
#   infer_time   : 0.3686
# ───────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────
# Dataset   : enn_rus2000_smote2000
# Timesteps : 288
# Train     : (4000, 288, 10) | Non-SEP=2000 | SEP=2000
# Val       : (1780, 288, 10) | Non-SEP=1763 | SEP=17
# Test      : (3559, 288, 10) | Non-SEP=3525 | SEP=34
# Ratio     : 1.0:1
# Params    : {'units': 128, 'layers': 1, 'dropout': 0.3, 'lr': 0.001, 'batch_size': 32}
# ──────────────────────────────────────────────────────────────────────
# Run 1 …
# Run 1: TSS=0.3738 | F1=0.1538 | Recall=0.4118 | Train=140.7s
# Run 2 …
# Run 2: TSS=0.3441 | F1=0.1429 | Recall=0.3824 | Train=155.4s
#
# ───────────────────────────────────────────────────────
#   GRU | enn_rus2000_smote2000
# ───────────────────────────────────────────────────────
#   Run 1: TP=14  TN=3391  FP=134  FN=20
#          TSS=0.3738  HSS1=0.1405  HSS2=0.1405  GSS=0.0756
#          Recall=0.4118  F1=0.1538  Acc=0.9567
#          Train=140.70s  Infer=0.3651s
#
#   Run 2: TP=13  TN=3390  FP=135  FN=21
#          TSS=0.3441  HSS1=0.1293  HSS2=0.1293  GSS=0.0691
#          Recall=0.3824  F1=0.1429  Acc=0.9562
#          Train=155.38s  Infer=0.3689s
#
#   ── Average of 2 runs ──
#   tss          : 0.3589
#   hss1         : 0.1349
#   hss2         : 0.1349
#   gss          : 0.0723
#   recall       : 0.3971
#   f1           : 0.1484
#   accuracy     : 0.9564
#   train_time   : 148.0418
#   infer_time   : 0.3670
# ───────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────
# Dataset   : enn_rus1000_smote1000
# Timesteps : 288
# Train     : (2000, 288, 10) | Non-SEP=1000 | SEP=1000
# Val       : (1780, 288, 10) | Non-SEP=1763 | SEP=17
# Test      : (3559, 288, 10) | Non-SEP=3525 | SEP=34
# Ratio     : 1.0:1
# Params    : {'units': 128, 'layers': 1, 'dropout': 0.3, 'lr': 0.001, 'batch_size': 32}
# ──────────────────────────────────────────────────────────────────────
# Run 1 …
# Run 1: TSS=0.4286 | F1=0.1616 | Recall=0.4706 | Train=77.5s
# Run 2 …
# Run 2: TSS=0.4161 | F1=0.1322 | Recall=0.4706 | Train=104.9s
#
# ───────────────────────────────────────────────────────
#   GRU | enn_rus1000_smote1000
# ───────────────────────────────────────────────────────
#   Run 1: TP=16  TN=3377  FP=148  FN=18
#          TSS=0.4286  HSS1=0.1481  HSS2=0.1481  GSS=0.0800
#          Recall=0.4706  F1=0.1616  Acc=0.9534
#          Train=77.54s  Infer=0.3645s
#
#   Run 2: TP=16  TN=3333  FP=192  FN=18
#          TSS=0.4161  HSS1=0.1177  HSS2=0.1177  GSS=0.0626
#          Recall=0.4706  F1=0.1322  Acc=0.9410
#          Train=104.89s  Infer=0.3583s
#
#   ── Average of 2 runs ──
#   tss          : 0.4224
#   hss1         : 0.1329
#   hss2         : 0.1329
#   gss          : 0.0713
#   recall       : 0.4706
#   f1           : 0.1469
#   accuracy     : 0.9472
#   train_time   : 91.2170
#   infer_time   : 0.3614
# ───────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────
# Dataset   : enn_rus500_smote500
# Timesteps : 288
# Train     : (1000, 288, 10) | Non-SEP=500 | SEP=500
# Val       : (1780, 288, 10) | Non-SEP=1763 | SEP=17
# Test      : (3559, 288, 10) | Non-SEP=3525 | SEP=34
# Ratio     : 1.0:1
# Params    : {'units': 128, 'layers': 1, 'dropout': 0.3, 'lr': 0.001, 'batch_size': 32}
# ──────────────────────────────────────────────────────────────────────
# Run 1 …
# Run 1: TSS=0.6391 | F1=0.1256 | Recall=0.7353 | Train=36.7s
# Run 2 …
# Run 2: TSS=0.6083 | F1=0.1194 | Recall=0.7059 | Train=45.7s
#
# ───────────────────────────────────────────────────────
#   GRU | enn_rus500_smote500
# ───────────────────────────────────────────────────────
#   Run 1: TP=25  TN=3186  FP=339  FN=9
#          TSS=0.6391  HSS1=0.1101  HSS2=0.1101  GSS=0.0582
#          Recall=0.7353  F1=0.1256  Acc=0.9022
#          Train=36.69s  Infer=0.3548s
#
#   Run 2: TP=24  TN=3181  FP=344  FN=10
#          TSS=0.6083  HSS1=0.1037  HSS2=0.1037  GSS=0.0547
#          Recall=0.7059  F1=0.1194  Acc=0.9005
#          Train=45.70s  Infer=0.3584s
#
#   ── Average of 2 runs ──
#   tss          : 0.6237
#   hss1         : 0.1069
#   hss2         : 0.1069
#   gss          : 0.0565
#   recall       : 0.7206
#   f1           : 0.1225
#   accuracy     : 0.9014
#   train_time   : 41.1903
#   infer_time   : 0.3566
# ───────────────────────────────────────────────────────
#
# ══════════════════════════════════════════════════════════════════════
# GRU ENN + SMOTE summary
# ══════════════════════════════════════════════════════════════════════
# Dataset                       Train N  Non-SEP      SEP      Ratio    Avg TSS     Avg F1   Avg Recall
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────
# enn_smote_balanced              24300    12150    12150       1.0x     0.1463     0.1176       0.1618
# enn_rus8000_smote8000           16000     8000     8000       1.0x     0.1702     0.1094       0.1912
# enn_rus4000_smote4000            8000     4000     4000       1.0x     0.3442     0.1404       0.3824
# enn_rus2000_smote2000            4000     2000     2000       1.0x     0.3589     0.1484       0.3971
# enn_rus1000_smote1000            2000     1000     1000       1.0x     0.4224     0.1469       0.4706
# enn_rus500_smote500              1000      500      500       1.0x     0.6237     0.1225       0.7206
#
# Best GRU ENN + SMOTE dataset:
#   Dataset : enn_rus500_smote500
#   Avg TSS : 0.6237
#   Params  : {'units': 128, 'layers': 1, 'dropout': 0.3, 'lr': 0.001, 'batch_size': 32}
#
# ✅ All GRU ENN + SMOTE experiments complete.
# Results saved to: /Users/samskanderi/SEP_DataAugmentation/results/
# Files: ['gru_enn_nonsep_1000.txt', 'gru_enn_nonsep_2000.txt', 'gru_enn_nonsep_4000.txt', 'gru_enn_nonsep_500.txt', 'gru_enn_nonsep_8000.txt', 'gru_enn_rus1000_smote1000.txt', 'gru_enn_rus2000_smote2000.txt', 'gru_enn_rus4000_smote4000.txt', 'gru_enn_rus500_smote500.txt', 'gru_enn_rus8000_smote8000.txt', 'gru_enn_smote_balanced.txt', 'gru_hybrid.txt', 'gru_hybrid_12h.txt', 'gru_hybrid_18h.txt', 'gru_hybrid_6h.txt', 'gru_hybrid_9h.txt', 'gru_hybrid_enn.txt', 'gru_hybrid_nearmiss.txt', 'gru_hybrid_tomek.txt', 'gru_log_all.txt', 'gru_minmax_all.txt', 'gru_zscore_all.txt', 'inceptiontime_enn_nonsep_1000.txt', 'inceptiontime_enn_nonsep_2000.txt', 'inceptiontime_enn_nonsep_4000.txt', 'inceptiontime_enn_nonsep_500.txt', 'inceptiontime_enn_nonsep_8000.txt', 'inceptiontime_enn_rus1000_smote1000.txt', 'inceptiontime_enn_rus2000_smote2000.txt', 'inceptiontime_enn_rus4000_smote4000.txt', 'inceptiontime_enn_rus500_smote500.txt', 'inceptiontime_enn_rus8000_smote8000.txt', 'inceptiontime_enn_smote_balanced.txt', 'inceptiontime_hybrid.txt', 'inceptiontime_hybrid_12h.txt', 'inceptiontime_hybrid_18h.txt', 'inceptiontime_hybrid_6h.txt', 'inceptiontime_hybrid_9h.txt', 'inceptiontime_hybrid_enn.txt', 'inceptiontime_hybrid_nearmiss.txt', 'inceptiontime_hybrid_tomek.txt', 'inceptiontime_log_all.txt', 'inceptiontime_minmax_all.txt', 'inceptiontime_zscore_all.txt', 'patchtst_enn_nonsep_1000.txt', 'patchtst_enn_nonsep_2000.txt', 'patchtst_enn_nonsep_4000.txt', 'patchtst_enn_nonsep_500.txt', 'patchtst_enn_nonsep_8000.txt', 'patchtst_enn_rus1000_smote1000.txt', 'patchtst_enn_rus2000_smote2000.txt', 'patchtst_enn_rus4000_smote4000.txt', 'patchtst_enn_rus500_smote500.txt', 'patchtst_enn_rus8000_smote8000.txt', 'patchtst_enn_smote_balanced.txt', 'patchtst_hybrid.txt', 'patchtst_hybrid_12h.txt', 'patchtst_hybrid_18h.txt', 'patchtst_hybrid_6h.txt', 'patchtst_hybrid_9h.txt', 'patchtst_hybrid_enn.txt', 'patchtst_hybrid_nearmiss.txt', 'patchtst_hybrid_tomek.txt', 'patchtst_log_all.txt', 'patchtst_minmax_all.txt', 'patchtst_zscore_all.txt', 'svm_enn_nonsep_1000.txt', 'svm_enn_nonsep_2000.txt', 'svm_enn_nonsep_4000.txt', 'svm_enn_nonsep_500.txt', 'svm_enn_nonsep_8000.txt', 'svm_enn_rus1000_smote1000.txt', 'svm_enn_rus2000_smote2000.txt', 'svm_enn_rus4000_smote4000.txt', 'svm_enn_rus500_smote500.txt', 'svm_enn_rus8000_smote8000.txt', 'svm_enn_smote_balanced.txt', 'svm_hybrid.txt', 'svm_hybrid_12h.txt', 'svm_hybrid_18h.txt', 'svm_hybrid_6h.txt', 'svm_hybrid_9h.txt', 'svm_log_all.txt', 'svm_minmax_all.txt', 'svm_zscore_all.txt']

# %%
import os
import time
import copy
import warnings
import numpy as np

import torch
import torch.nn as nn
from transformers import PatchTSTConfig, PatchTSTForClassification

warnings.filterwarnings("ignore")

device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print(f"Using device: {device}")


def patchtst_label(p):
    return (
        f"patch={p['patch_length']}  "
        f"stride={p['patch_stride']}  "
        f"d={p['d_model']}  "
        f"heads={p['num_attention_heads']}  "
        f"layers={p['num_hidden_layers']}  "
        f"drop={p['dropout']}  "
        f"lr={p['lr']}  "
        f"bs={p['batch_size']}"
    )


def build_patchtst_model(params, seq_len, n_channels):
    config = PatchTSTConfig(
        num_input_channels=n_channels,
        context_length=seq_len,
        num_targets=2,

        patch_length=params["patch_length"],
        patch_stride=params["patch_stride"],

        d_model=params["d_model"],
        num_attention_heads=params["num_attention_heads"],
        num_hidden_layers=params["num_hidden_layers"],
        ffn_dim=params["ffn_dim"],

        attention_dropout=params["dropout"],
        positional_dropout=params["dropout"],
        ff_dropout=params["dropout"],
        head_dropout=params["dropout"],

        pooling_type="mean",
        use_cls_token=True,
        norm_type="layernorm",
        channel_attention=True,
        problem_type="single_label_classification",
        scaling=None,
    )

    return PatchTSTForClassification(config)


def train_and_evaluate_patchtst(
    params,
    X_train, y_train,
    X_val, y_val,
    X_test, y_test,
    class_ratio,
    max_epochs=30,
    patience=3
):
    X_tr = torch.tensor(X_train, dtype=torch.float32).to(device)
    y_tr = torch.tensor(y_train, dtype=torch.long).to(device)

    X_va = torch.tensor(X_val, dtype=torch.float32).to(device)
    y_va = torch.tensor(y_val, dtype=torch.long).to(device)

    X_te = torch.tensor(X_test, dtype=torch.float32).to(device)

    seq_len = X_train.shape[1]
    n_channels = X_train.shape[2]

    model = build_patchtst_model(
        params,
        seq_len=seq_len,
        n_channels=n_channels
    ).to(device)

    class_weights = torch.tensor(
        [1.0, float(class_ratio)],
        dtype=torch.float32
    ).to(device)

    criterion = nn.CrossEntropyLoss(weight=class_weights)

    optimizer = torch.optim.AdamW(
        model.parameters(),
        lr=params["lr"],
        weight_decay=1e-4
    )

    batch_size = params["batch_size"]
    n_samples = X_tr.shape[0]

    best_val_loss = float("inf")
    best_state = None
    patience_count = 0

    t0 = time.time()

    for epoch in range(max_epochs):
        model.train()

        perm = torch.randperm(n_samples, device=device)

        for i in range(0, n_samples, batch_size):
            idx = perm[i:i + batch_size]

            xb = X_tr[idx]
            yb = y_tr[idx]

            optimizer.zero_grad()

            outputs = model(past_values=xb)
            logits = outputs.prediction_logits

            loss = criterion(logits, yb)
            loss.backward()

            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_outputs = model(past_values=X_va)
            val_logits = val_outputs.prediction_logits
            val_loss = criterion(val_logits, y_va).item()

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_state = copy.deepcopy(model.state_dict())
            patience_count = 0
        else:
            patience_count += 1
            if patience_count >= patience:
                break

    train_time = time.time() - t0

    if best_state is not None:
        model.load_state_dict(best_state)

    model.eval()
    t0 = time.time()

    with torch.no_grad():
        test_outputs = model(past_values=X_te)
        test_logits = test_outputs.prediction_logits
        y_pred = torch.argmax(test_logits, dim=1).cpu().numpy()

    infer_time = time.time() - t0

    metrics = compute_metrics(y_test.astype(int), y_pred.astype(int))
    metrics["train_time"] = train_time
    metrics["infer_time"] = infer_time

    return metrics, model
# Out:
# Using device: mps

# %%
# ══════════════════════════════════════════════════════════════
# PATCHTST FINAL EXPERIMENTS — ENN + SMOTE / RUS + SMOTE
# Uses fixed best hyperparameters selected previously
# Best params: patch=12, stride=12, d=32, heads=4, layers=1,
#              dropout=0.2, lr=0.001, batch_size=128
# Datasets:
#   enn_smote_balanced
#   enn_rus8000_smote8000
#   enn_rus4000_smote4000
#   enn_rus2000_smote2000
#   enn_rus1000_smote1000
#   enn_rus500_smote500
# ══════════════════════════════════════════════════════════════

import os
import copy
import numpy as np

RESULTS_DIR = "./results"
os.makedirs(RESULTS_DIR, exist_ok=True)

# ---------------------------------------------------------
# Fixed best PatchTST hyperparameters
# ---------------------------------------------------------
best_params = {
    "patch_length": 12,
    "patch_stride": 12,
    "d_model": 32,
    "num_attention_heads": 4,
    "num_hidden_layers": 1,
    "ffn_dim": 128,
    "dropout": 0.2,
    "lr": 0.001,
    "batch_size": 128,
}

TARGET_VARIANTS = [
    "enn_smote_balanced",
    "enn_rus8000_smote8000",
    "enn_rus4000_smote4000",
    "enn_rus2000_smote2000",
    "enn_rus1000_smote1000",
    "enn_rus500_smote500",
]


def patchtst_label(p):
    return (
        f"patch={p['patch_length']}  "
        f"stride={p['patch_stride']}  "
        f"d={p['d_model']}  "
        f"heads={p['num_attention_heads']}  "
        f"layers={p['num_hidden_layers']}  "
        f"drop={p['dropout']}  "
        f"lr={p['lr']}  "
        f"bs={p['batch_size']}"
    )


print(f"{'═' * 70}")
print("  Classifier : Hugging Face PatchTST")
print("  Experiment : ENN + SMOTE / RUS + SMOTE")
print(f"  Best params: {patchtst_label(best_params)}")
print(f"{'═' * 70}")


# ---------------------------------------------------------
# Run final PatchTST experiments on SMOTE datasets
# ---------------------------------------------------------
all_patchtst_smote_results = {}

for dataset_key in TARGET_VARIANTS:

    if dataset_key not in datasets_smote:
        print(f"[{dataset_key}] not found — skipping")
        continue

    d = datasets_smote[dataset_key]

    timesteps = d["X_train"].shape[1]

    train_counts = np.bincount(d["y_train"].astype(int), minlength=2)
    val_counts   = np.bincount(d["y_val"].astype(int), minlength=2)
    test_counts  = np.bincount(d["y_test"].astype(int), minlength=2)

    cr = train_counts[0] / train_counts[1]

    print("\n" + "─" * 70)
    print(f"Dataset   : {dataset_key}")
    print(f"Timesteps : {timesteps}")
    print(f"Train     : {d['X_train'].shape} | Non-SEP={train_counts[0]} | SEP={train_counts[1]}")
    print(f"Val       : {d['X_val'].shape} | Non-SEP={val_counts[0]} | SEP={val_counts[1]}")
    print(f"Test      : {d['X_test'].shape} | Non-SEP={test_counts[0]} | SEP={test_counts[1]}")
    print(f"Ratio     : {cr:.1f}:1")
    print(f"Params    : {patchtst_label(best_params)}")
    print("─" * 70)

    metrics_list = []

    for run in range(2):

        print(f"Run {run + 1} …", flush=True)

        metrics, _ = train_and_evaluate_patchtst(
            copy.deepcopy(best_params),
            d["X_train"], d["y_train"],
            d["X_val"],   d["y_val"],
            d["X_test"],  d["y_test"],
            class_ratio=cr,
            max_epochs=30,
            patience=3
        )

        metrics_list.append(metrics)

        precision_text = (
            f" | Precision={metrics['precision']:.4f}"
            if "precision" in metrics else ""
        )

        print(
            f"Run {run + 1}: "
            f"TSS={metrics['tss']:.4f} | "
            f"F1={metrics['f1']:.4f} | "
            f"Recall={metrics['recall']:.4f}"
            f"{precision_text} | "
            f"Train={metrics['train_time']:.1f}s"
        )

    all_patchtst_smote_results[dataset_key] = metrics_list

    filepath = os.path.join(RESULTS_DIR, f"patchtst_{dataset_key}.txt")
    save_results(metrics_list, filepath)
    print_results(metrics_list, f"PatchTST | {dataset_key}")


# ---------------------------------------------------------
# Select best SMOTE dataset by average TSS
# ---------------------------------------------------------
best_dataset = None
best_avg_tss = -np.inf

print("\n" + "═" * 70)
print("PatchTST ENN + SMOTE summary")
print("═" * 70)

print(
    f"{'Dataset':<26} "
    f"{'Train N':>10} "
    f"{'Non-SEP':>8} "
    f"{'SEP':>8} "
    f"{'Ratio':>10} "
    f"{'Avg TSS':>10} "
    f"{'Avg F1':>10} "
    f"{'Avg Recall':>12}"
)

print("─" * 105)

for dataset_key, metrics_list in all_patchtst_smote_results.items():

    d = datasets_smote[dataset_key]

    counts = np.bincount(d["y_train"].astype(int), minlength=2)
    ratio = counts[0] / counts[1]

    avg_tss = np.mean([m["tss"] for m in metrics_list])
    avg_f1 = np.mean([m["f1"] for m in metrics_list])
    avg_recall = np.mean([m["recall"] for m in metrics_list])

    print(
        f"{dataset_key:<26} "
        f"{len(d['y_train']):>10} "
        f"{counts[0]:>8} "
        f"{counts[1]:>8} "
        f"{ratio:>9.1f}x "
        f"{avg_tss:>10.4f} "
        f"{avg_f1:>10.4f} "
        f"{avg_recall:>12.4f}"
    )

    if avg_tss > best_avg_tss:
        best_avg_tss = avg_tss
        best_dataset = dataset_key


print("\nBest PatchTST ENN + SMOTE dataset:")
print(f"  Dataset : {best_dataset}")
print(f"  Avg TSS : {best_avg_tss:.4f}")
print(f"  Params  : {patchtst_label(best_params)}")

print("\n✅ All PatchTST ENN + SMOTE experiments complete.")
print(f"Results saved to: {os.path.abspath(RESULTS_DIR)}/")
print(f"Files: {sorted([f for f in os.listdir(RESULTS_DIR) if f.endswith('.txt')])}")
# Out:
# ══════════════════════════════════════════════════════════════════════
#   Classifier : Hugging Face PatchTST
#   Experiment : ENN + SMOTE / RUS + SMOTE
#   Best params: patch=12  stride=12  d=32  heads=4  layers=1  drop=0.2  lr=0.001  bs=128
# ══════════════════════════════════════════════════════════════════════
#
# ──────────────────────────────────────────────────────────────────────
# Dataset   : enn_smote_balanced
# Timesteps : 288
# Train     : (24300, 288, 10) | Non-SEP=12150 | SEP=12150
# Val       : (1780, 288, 10) | Non-SEP=1763 | SEP=17
# Test      : (3559, 288, 10) | Non-SEP=3525 | SEP=34
# Ratio     : 1.0:1
# Params    : patch=12  stride=12  d=32  heads=4  layers=1  drop=0.2  lr=0.001  bs=128
# ──────────────────────────────────────────────────────────────────────
# Run 1 …
# Run 1: TSS=0.3830 | F1=0.0634 | Recall=0.5294 | Train=51.5s
# Run 2 …
# Run 2: TSS=0.6439 | F1=0.1070 | Recall=0.7647 | Train=35.1s
#
# ───────────────────────────────────────────────────────
#   PatchTST | enn_smote_balanced
# ───────────────────────────────────────────────────────
#   Run 1: TP=18  TN=3009  FP=516  FN=16
#          TSS=0.3830  HSS1=0.0462  HSS2=0.0462  GSS=0.0237
#          Recall=0.5294  F1=0.0634  Acc=0.8505
#          Train=51.48s  Infer=0.6121s
#
#   Run 2: TP=26  TN=3099  FP=426  FN=8
#          TSS=0.6439  HSS1=0.0908  HSS2=0.0908  GSS=0.0476
#          Recall=0.7647  F1=0.1070  Acc=0.8781
#          Train=35.08s  Infer=0.7809s
#
#   ── Average of 2 runs ──
#   tss          : 0.5134
#   hss1         : 0.0685
#   hss2         : 0.0685
#   gss          : 0.0356
#   recall       : 0.6471
#   f1           : 0.0852
#   accuracy     : 0.8643
#   train_time   : 43.2817
#   infer_time   : 0.6965
# ───────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────
# Dataset   : enn_rus8000_smote8000
# Timesteps : 288
# Train     : (16000, 288, 10) | Non-SEP=8000 | SEP=8000
# Val       : (1780, 288, 10) | Non-SEP=1763 | SEP=17
# Test      : (3559, 288, 10) | Non-SEP=3525 | SEP=34
# Ratio     : 1.0:1
# Params    : patch=12  stride=12  d=32  heads=4  layers=1  drop=0.2  lr=0.001  bs=128
# ──────────────────────────────────────────────────────────────────────
# Run 1 …
# Run 1: TSS=0.4734 | F1=0.1073 | Recall=0.5588 | Train=36.7s
# Run 2 …
# Run 2: TSS=0.6074 | F1=0.1185 | Recall=0.7059 | Train=31.6s
#
# ───────────────────────────────────────────────────────
#   PatchTST | enn_rus8000_smote8000
# ───────────────────────────────────────────────────────
#   Run 1: TP=19  TN=3224  FP=301  FN=15
#          TSS=0.4734  HSS1=0.0917  HSS2=0.0917  GSS=0.0480
#          Recall=0.5588  F1=0.1073  Acc=0.9112
#          Train=36.66s  Infer=0.5148s
#
#   Run 2: TP=24  TN=3178  FP=347  FN=10
#          TSS=0.6074  HSS1=0.1028  HSS2=0.1028  GSS=0.0542
#          Recall=0.7059  F1=0.1185  Acc=0.8997
#          Train=31.63s  Infer=0.6081s
#
#   ── Average of 2 runs ──
#   tss          : 0.5404
#   hss1         : 0.0972
#   hss2         : 0.0972
#   gss          : 0.0511
#   recall       : 0.6324
#   f1           : 0.1129
#   accuracy     : 0.9055
#   train_time   : 34.1462
#   infer_time   : 0.5615
# ───────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────
# Dataset   : enn_rus4000_smote4000
# Timesteps : 288
# Train     : (8000, 288, 10) | Non-SEP=4000 | SEP=4000
# Val       : (1780, 288, 10) | Non-SEP=1763 | SEP=17
# Test      : (3559, 288, 10) | Non-SEP=3525 | SEP=34
# Ratio     : 1.0:1
# Params    : patch=12  stride=12  d=32  heads=4  layers=1  drop=0.2  lr=0.001  bs=128
# ──────────────────────────────────────────────────────────────────────
# Run 1 …
# Run 1: TSS=0.5876 | F1=0.1011 | Recall=0.7059 | Train=16.8s
# Run 2 …
# Run 2: TSS=0.5825 | F1=0.0974 | Recall=0.7059 | Train=27.5s
#
# ───────────────────────────────────────────────────────
#   PatchTST | enn_rus4000_smote4000
# ───────────────────────────────────────────────────────
#   Run 1: TP=24  TN=3108  FP=417  FN=10
#          TSS=0.5876  HSS1=0.0848  HSS2=0.0848  GSS=0.0443
#          Recall=0.7059  F1=0.1011  Acc=0.8800
#          Train=16.83s  Infer=0.4982s
#
#   Run 2: TP=24  TN=3090  FP=435  FN=10
#          TSS=0.5825  HSS1=0.0810  HSS2=0.0810  GSS=0.0422
#          Recall=0.7059  F1=0.0974  Acc=0.8750
#          Train=27.52s  Infer=0.9521s
#
#   ── Average of 2 runs ──
#   tss          : 0.5850
#   hss1         : 0.0829
#   hss2         : 0.0829
#   gss          : 0.0433
#   recall       : 0.7059
#   f1           : 0.0992
#   accuracy     : 0.8775
#   train_time   : 22.1773
#   infer_time   : 0.7251
# ───────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────
# Dataset   : enn_rus2000_smote2000
# Timesteps : 288
# Train     : (4000, 288, 10) | Non-SEP=2000 | SEP=2000
# Val       : (1780, 288, 10) | Non-SEP=1763 | SEP=17
# Test      : (3559, 288, 10) | Non-SEP=3525 | SEP=34
# Ratio     : 1.0:1
# Params    : patch=12  stride=12  d=32  heads=4  layers=1  drop=0.2  lr=0.001  bs=128
# ──────────────────────────────────────────────────────────────────────
# Run 1 …
# Run 1: TSS=0.6063 | F1=0.1174 | Recall=0.7059 | Train=16.0s
# Run 2 …
# Run 2: TSS=0.6670 | F1=0.1061 | Recall=0.7941 | Train=13.7s
#
# ───────────────────────────────────────────────────────
#   PatchTST | enn_rus2000_smote2000
# ───────────────────────────────────────────────────────
#   Run 1: TP=24  TN=3174  FP=351  FN=10
#          TSS=0.6063  HSS1=0.1016  HSS2=0.1016  GSS=0.0535
#          Recall=0.7059  F1=0.1174  Acc=0.8986
#          Train=16.03s  Infer=0.4037s
#
#   Run 2: TP=27  TN=3077  FP=448  FN=7
#          TSS=0.6670  HSS1=0.0899  HSS2=0.0899  GSS=0.0470
#          Recall=0.7941  F1=0.1061  Acc=0.8722
#          Train=13.74s  Infer=0.3870s
#
#   ── Average of 2 runs ──
#   tss          : 0.6367
#   hss1         : 0.0957
#   hss2         : 0.0957
#   gss          : 0.0503
#   recall       : 0.7500
#   f1           : 0.1117
#   accuracy     : 0.8854
#   train_time   : 14.8809
#   infer_time   : 0.3953
# ───────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────
# Dataset   : enn_rus1000_smote1000
# Timesteps : 288
# Train     : (2000, 288, 10) | Non-SEP=1000 | SEP=1000
# Val       : (1780, 288, 10) | Non-SEP=1763 | SEP=17
# Test      : (3559, 288, 10) | Non-SEP=3525 | SEP=34
# Ratio     : 1.0:1
# Params    : patch=12  stride=12  d=32  heads=4  layers=1  drop=0.2  lr=0.001  bs=128
# ──────────────────────────────────────────────────────────────────────
# Run 1 …
# Run 1: TSS=0.6358 | F1=0.0872 | Recall=0.7941 | Train=5.8s
# Run 2 …
# Run 2: TSS=0.6062 | F1=0.0973 | Recall=0.7353 | Train=5.7s
#
# ───────────────────────────────────────────────────────
#   PatchTST | enn_rus1000_smote1000
# ───────────────────────────────────────────────────────
#   Run 1: TP=27  TN=2967  FP=558  FN=7
#          TSS=0.6358  HSS1=0.0705  HSS2=0.0705  GSS=0.0365
#          Recall=0.7941  F1=0.0872  Acc=0.8412
#          Train=5.77s  Infer=0.4377s
#
#   Run 2: TP=25  TN=3070  FP=455  FN=9
#          TSS=0.6062  HSS1=0.0809  HSS2=0.0809  GSS=0.0421
#          Recall=0.7353  F1=0.0973  Acc=0.8696
#          Train=5.66s  Infer=0.3746s
#
#   ── Average of 2 runs ──
#   tss          : 0.6210
#   hss1         : 0.0757
#   hss2         : 0.0757
#   gss          : 0.0393
#   recall       : 0.7647
#   f1           : 0.0923
#   accuracy     : 0.8554
#   train_time   : 5.7155
#   infer_time   : 0.4061
# ───────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────
# Dataset   : enn_rus500_smote500
# Timesteps : 288
# Train     : (1000, 288, 10) | Non-SEP=500 | SEP=500
# Val       : (1780, 288, 10) | Non-SEP=1763 | SEP=17
# Test      : (3559, 288, 10) | Non-SEP=3525 | SEP=34
# Ratio     : 1.0:1
# Params    : patch=12  stride=12  d=32  heads=4  layers=1  drop=0.2  lr=0.001  bs=128
# ──────────────────────────────────────────────────────────────────────
# Run 1 …
# Run 1: TSS=0.5629 | F1=0.0854 | Recall=0.7059 | Train=5.7s
# Run 2 …
# Run 2: TSS=0.0000 | F1=0.0000 | Recall=0.0000 | Train=2.3s
#
# ───────────────────────────────────────────────────────
#   PatchTST | enn_rus500_smote500
# ───────────────────────────────────────────────────────
#   Run 1: TP=24  TN=3021  FP=504  FN=10
#          TSS=0.5629  HSS1=0.0687  HSS2=0.0687  GSS=0.0356
#          Recall=0.7059  F1=0.0854  Acc=0.8556
#          Train=5.71s  Infer=0.3652s
#
#   Run 2: TP=0  TN=3525  FP=0  FN=34
#          TSS=0.0000  HSS1=0.0000  HSS2=0.0000  GSS=0.0000
#          Recall=0.0000  F1=0.0000  Acc=0.9904
#          Train=2.26s  Infer=0.4205s
#
#   ── Average of 2 runs ──
#   tss          : 0.2815
#   hss1         : 0.0343
#   hss2         : 0.0343
#   gss          : 0.0178
#   recall       : 0.3529
#   f1           : 0.0427
#   accuracy     : 0.9230
#   train_time   : 3.9852
#   infer_time   : 0.3929
# ───────────────────────────────────────────────────────
#
# ══════════════════════════════════════════════════════════════════════
# PatchTST ENN + SMOTE summary
# ══════════════════════════════════════════════════════════════════════
# Dataset                       Train N  Non-SEP      SEP      Ratio    Avg TSS     Avg F1   Avg Recall
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────
# enn_smote_balanced              24300    12150    12150       1.0x     0.5134     0.0852       0.6471
# enn_rus8000_smote8000           16000     8000     8000       1.0x     0.5404     0.1129       0.6324
# enn_rus4000_smote4000            8000     4000     4000       1.0x     0.5850     0.0992       0.7059
# enn_rus2000_smote2000            4000     2000     2000       1.0x     0.6367     0.1117       0.7500
# enn_rus1000_smote1000            2000     1000     1000       1.0x     0.6210     0.0923       0.7647
# enn_rus500_smote500              1000      500      500       1.0x     0.2815     0.0427       0.3529
#
# Best PatchTST ENN + SMOTE dataset:
#   Dataset : enn_rus2000_smote2000
#   Avg TSS : 0.6367
#   Params  : patch=12  stride=12  d=32  heads=4  layers=1  drop=0.2  lr=0.001  bs=128
#
# ✅ All PatchTST ENN + SMOTE experiments complete.
# Results saved to: /Users/samskanderi/SEP_DataAugmentation/results/
# Files: ['gru_enn_nonsep_1000.txt', 'gru_enn_nonsep_2000.txt', 'gru_enn_nonsep_4000.txt', 'gru_enn_nonsep_500.txt', 'gru_enn_nonsep_8000.txt', 'gru_enn_rus1000_smote1000.txt', 'gru_enn_rus2000_smote2000.txt', 'gru_enn_rus4000_smote4000.txt', 'gru_enn_rus500_smote500.txt', 'gru_enn_rus8000_smote8000.txt', 'gru_enn_smote_balanced.txt', 'gru_hybrid.txt', 'gru_hybrid_12h.txt', 'gru_hybrid_18h.txt', 'gru_hybrid_6h.txt', 'gru_hybrid_9h.txt', 'gru_hybrid_enn.txt', 'gru_hybrid_nearmiss.txt', 'gru_hybrid_tomek.txt', 'gru_log_all.txt', 'gru_minmax_all.txt', 'gru_zscore_all.txt', 'inceptiontime_enn_nonsep_1000.txt', 'inceptiontime_enn_nonsep_2000.txt', 'inceptiontime_enn_nonsep_4000.txt', 'inceptiontime_enn_nonsep_500.txt', 'inceptiontime_enn_nonsep_8000.txt', 'inceptiontime_enn_rus1000_smote1000.txt', 'inceptiontime_enn_rus2000_smote2000.txt', 'inceptiontime_enn_rus4000_smote4000.txt', 'inceptiontime_enn_rus500_smote500.txt', 'inceptiontime_enn_rus8000_smote8000.txt', 'inceptiontime_enn_smote_balanced.txt', 'inceptiontime_hybrid.txt', 'inceptiontime_hybrid_12h.txt', 'inceptiontime_hybrid_18h.txt', 'inceptiontime_hybrid_6h.txt', 'inceptiontime_hybrid_9h.txt', 'inceptiontime_hybrid_enn.txt', 'inceptiontime_hybrid_nearmiss.txt', 'inceptiontime_hybrid_tomek.txt', 'inceptiontime_log_all.txt', 'inceptiontime_minmax_all.txt', 'inceptiontime_zscore_all.txt', 'patchtst_enn_nonsep_1000.txt', 'patchtst_enn_nonsep_2000.txt', 'patchtst_enn_nonsep_4000.txt', 'patchtst_enn_nonsep_500.txt', 'patchtst_enn_nonsep_8000.txt', 'patchtst_enn_rus1000_smote1000.txt', 'patchtst_enn_rus2000_smote2000.txt', 'patchtst_enn_rus4000_smote4000.txt', 'patchtst_enn_rus500_smote500.txt', 'patchtst_enn_rus8000_smote8000.txt', 'patchtst_enn_smote_balanced.txt', 'patchtst_hybrid.txt', 'patchtst_hybrid_12h.txt', 'patchtst_hybrid_18h.txt', 'patchtst_hybrid_6h.txt', 'patchtst_hybrid_9h.txt', 'patchtst_hybrid_enn.txt', 'patchtst_hybrid_nearmiss.txt', 'patchtst_hybrid_tomek.txt', 'patchtst_log_all.txt', 'patchtst_minmax_all.txt', 'patchtst_zscore_all.txt', 'svm_enn_nonsep_1000.txt', 'svm_enn_nonsep_2000.txt', 'svm_enn_nonsep_4000.txt', 'svm_enn_nonsep_500.txt', 'svm_enn_nonsep_8000.txt', 'svm_enn_rus1000_smote1000.txt', 'svm_enn_rus2000_smote2000.txt', 'svm_enn_rus4000_smote4000.txt', 'svm_enn_rus500_smote500.txt', 'svm_enn_rus8000_smote8000.txt', 'svm_enn_smote_balanced.txt', 'svm_hybrid.txt', 'svm_hybrid_12h.txt', 'svm_hybrid_18h.txt', 'svm_hybrid_6h.txt', 'svm_hybrid_9h.txt', 'svm_log_all.txt', 'svm_minmax_all.txt', 'svm_zscore_all.txt']

# %%
import os
import time
import copy
import warnings
import numpy as np

import torch
import torch.nn as nn

warnings.filterwarnings("ignore")

device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print(f"Using device: {device}")


# ══════════════════════════════════════════════════════════════
# INCEPTIONTIME MODEL
# ══════════════════════════════════════════════════════════════

class InceptionModule(nn.Module):
    def __init__(
        self,
        in_channels,
        out_channels=32,
        kernel_sizes=(9, 19, 39),
        bottleneck_channels=32
    ):
        super(InceptionModule, self).__init__()

        if in_channels > 1:
            self.bottleneck = nn.Conv1d(
                in_channels,
                bottleneck_channels,
                kernel_size=1,
                bias=False
            )
            conv_in_channels = bottleneck_channels
        else:
            self.bottleneck = nn.Identity()
            conv_in_channels = in_channels

        self.conv_list = nn.ModuleList([
            nn.Conv1d(
                conv_in_channels,
                out_channels,
                kernel_size=k,
                padding=k // 2,
                bias=False
            )
            for k in kernel_sizes
        ])

        self.maxpool_conv = nn.Sequential(
            nn.MaxPool1d(kernel_size=3, stride=1, padding=1),
            nn.Conv1d(in_channels, out_channels, kernel_size=1, bias=False)
        )

        total_out_channels = out_channels * (len(kernel_sizes) + 1)

        self.bn = nn.BatchNorm1d(total_out_channels)
        self.relu = nn.ReLU()

    def forward(self, x):
        x_bottleneck = self.bottleneck(x)

        conv_outputs = [
            conv(x_bottleneck)
            for conv in self.conv_list
        ]

        pool_output = self.maxpool_conv(x)

        out = torch.cat(conv_outputs + [pool_output], dim=1)
        out = self.bn(out)
        out = self.relu(out)

        return out


class InceptionBlock(nn.Module):
    def __init__(self, in_channels, out_channels=32, depth=3, use_residual=True):
        super(InceptionBlock, self).__init__()

        self.use_residual = use_residual
        self.depth = depth

        modules = []
        current_channels = in_channels

        for _ in range(depth):
            module = InceptionModule(
                in_channels=current_channels,
                out_channels=out_channels
            )
            modules.append(module)

            current_channels = out_channels * 4

        self.inception_modules = nn.ModuleList(modules)

        if use_residual:
            self.residual = nn.Sequential(
                nn.Conv1d(in_channels, current_channels, kernel_size=1, bias=False),
                nn.BatchNorm1d(current_channels)
            )
            self.relu = nn.ReLU()

    def forward(self, x):
        residual = x

        out = x
        for module in self.inception_modules:
            out = module(out)

        if self.use_residual:
            residual = self.residual(residual)
            out = self.relu(out + residual)

        return out


class InceptionTimeClassifier(nn.Module):
    def __init__(self, input_channels, out_channels=32, depth=6, dropout=0.3):
        super(InceptionTimeClassifier, self).__init__()

        block_depth = max(1, depth // 2)

        self.block1 = InceptionBlock(
            in_channels=input_channels,
            out_channels=out_channels,
            depth=block_depth,
            use_residual=True
        )

        block1_channels = out_channels * 4

        self.block2 = InceptionBlock(
            in_channels=block1_channels,
            out_channels=out_channels,
            depth=block_depth,
            use_residual=True
        )

        final_channels = out_channels * 4

        self.gap = nn.AdaptiveAvgPool1d(1)
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(final_channels, 1)

    def forward(self, x):
        # Input shape: (batch, timesteps, features)
        # Conv1d expects: (batch, features, timesteps)
        x = x.permute(0, 2, 1)

        x = self.block1(x)
        x = self.block2(x)

        x = self.gap(x).squeeze(-1)
        x = self.dropout(x)

        return self.fc(x).squeeze()


# ══════════════════════════════════════════════════════════════
# TRAIN AND EVALUATE INCEPTIONTIME
# ══════════════════════════════════════════════════════════════

def train_and_evaluate_inception(
    params,
    X_train, y_train,
    X_val, y_val,
    X_test, y_test,
    class_ratio,
    max_epochs=30,
    patience=3
):
    X_tr = torch.tensor(X_train, dtype=torch.float32).to(device)
    y_tr = torch.tensor(y_train, dtype=torch.float32).to(device)

    X_va = torch.tensor(X_val, dtype=torch.float32).to(device)
    y_va = torch.tensor(y_val, dtype=torch.float32).to(device)

    X_te = torch.tensor(X_test, dtype=torch.float32).to(device)

    input_channels = X_train.shape[2]

    model = InceptionTimeClassifier(
        input_channels=input_channels,
        out_channels=params["out_channels"],
        depth=params["depth"],
        dropout=params["dropout"]
    ).to(device)

    pos_weight = torch.tensor([float(class_ratio)], dtype=torch.float32).to(device)
    criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)

    optimizer = torch.optim.AdamW(
        model.parameters(),
        lr=params["lr"],
        weight_decay=1e-4
    )

    batch_size = params["batch_size"]
    n_samples = X_tr.shape[0]

    best_val_loss = float("inf")
    best_state = None
    patience_count = 0

    t0 = time.time()

    for epoch in range(max_epochs):
        model.train()

        perm = torch.randperm(n_samples, device=device)

        for i in range(0, n_samples, batch_size):
            idx = perm[i:i + batch_size]

            xb = X_tr[idx]
            yb = y_tr[idx]

            optimizer.zero_grad()

            logits = model(xb)
            loss = criterion(logits, yb)

            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_logits = model(X_va)
            val_loss = criterion(val_logits, y_va).item()

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_state = copy.deepcopy(model.state_dict())
            patience_count = 0
        else:
            patience_count += 1

            if patience_count >= patience:
                break

    train_time = time.time() - t0

    if best_state is not None:
        model.load_state_dict(best_state)

    model.eval()
    t0 = time.time()

    with torch.no_grad():
        y_prob = torch.sigmoid(model(X_te)).cpu().numpy()

    y_pred = (y_prob >= 0.5).astype(int)
    infer_time = time.time() - t0

    metrics = compute_metrics(y_test.astype(int), y_pred.astype(int))
    metrics["train_time"] = train_time
    metrics["infer_time"] = infer_time

    return metrics, model
# Out:
# Using device: mps

# %%
# ══════════════════════════════════════════════════════════════
# INCEPTIONTIME FINAL EXPERIMENTS — ENN + SMOTE / RUS + SMOTE
# Uses fixed best hyperparameters selected previously
# Best params: channels=16, depth=6, dropout=0.3, lr=0.005, batch_size=128
# Datasets:
#   enn_smote_balanced
#   enn_rus8000_smote8000
#   enn_rus4000_smote4000
#   enn_rus2000_smote2000
#   enn_rus1000_smote1000
#   enn_rus500_smote500
# ══════════════════════════════════════════════════════════════

import os
import copy
import numpy as np

RESULTS_DIR = "./results"
os.makedirs(RESULTS_DIR, exist_ok=True)

# ---------------------------------------------------------
# Fixed best InceptionTime hyperparameters
# ---------------------------------------------------------
best_params = {
    "out_channels": 16,
    "depth": 6,
    "dropout": 0.3,
    "lr": 0.005,
    "batch_size": 128
}

TARGET_VARIANTS = [
    "enn_smote_balanced",
    "enn_rus8000_smote8000",
    "enn_rus4000_smote4000",
    "enn_rus2000_smote2000",
    "enn_rus1000_smote1000",
    "enn_rus500_smote500",
]


def inception_label(p):
    return (
        f"channels={p['out_channels']}  "
        f"depth={p['depth']}  "
        f"drop={p['dropout']}  "
        f"lr={p['lr']}  "
        f"bs={p['batch_size']}"
    )


print(f"{'═' * 70}")
print("  Classifier : InceptionTime")
print("  Experiment : ENN + SMOTE / RUS + SMOTE")
print(f"  Best params: {inception_label(best_params)}")
print(f"{'═' * 70}")


# ---------------------------------------------------------
# Run final InceptionTime experiments on SMOTE datasets
# ---------------------------------------------------------
all_inception_smote_results = {}

for dataset_key in TARGET_VARIANTS:

    if dataset_key not in datasets_smote:
        print(f"[{dataset_key}] not found — skipping")
        continue

    d = datasets_smote[dataset_key]

    timesteps = d["X_train"].shape[1]

    train_counts = np.bincount(d["y_train"].astype(int), minlength=2)
    val_counts   = np.bincount(d["y_val"].astype(int), minlength=2)
    test_counts  = np.bincount(d["y_test"].astype(int), minlength=2)

    cr = train_counts[0] / train_counts[1]

    print("\n" + "─" * 70)
    print(f"Dataset   : {dataset_key}")
    print(f"Timesteps : {timesteps}")
    print(f"Train     : {d['X_train'].shape} | Non-SEP={train_counts[0]} | SEP={train_counts[1]}")
    print(f"Val       : {d['X_val'].shape} | Non-SEP={val_counts[0]} | SEP={val_counts[1]}")
    print(f"Test      : {d['X_test'].shape} | Non-SEP={test_counts[0]} | SEP={test_counts[1]}")
    print(f"Ratio     : {cr:.1f}:1")
    print(f"Params    : {inception_label(best_params)}")
    print("─" * 70)

    metrics_list = []

    for run in range(2):

        print(f"Run {run + 1} …", flush=True)

        metrics, _ = train_and_evaluate_inception(
            copy.deepcopy(best_params),
            d["X_train"], d["y_train"],
            d["X_val"],   d["y_val"],
            d["X_test"],  d["y_test"],
            class_ratio=cr,
            max_epochs=30,
            patience=3
        )

        metrics_list.append(metrics)

        precision_text = (
            f" | Precision={metrics['precision']:.4f}"
            if "precision" in metrics else ""
        )

        print(
            f"Run {run + 1}: "
            f"TSS={metrics['tss']:.4f} | "
            f"F1={metrics['f1']:.4f} | "
            f"Recall={metrics['recall']:.4f}"
            f"{precision_text} | "
            f"Train={metrics['train_time']:.1f}s"
        )

    all_inception_smote_results[dataset_key] = metrics_list

    filepath = os.path.join(RESULTS_DIR, f"inceptiontime_{dataset_key}.txt")
    save_results(metrics_list, filepath)
    print_results(metrics_list, f"InceptionTime | {dataset_key}")


# ---------------------------------------------------------
# Select best SMOTE dataset by average TSS
# ---------------------------------------------------------
best_dataset = None
best_avg_tss = -np.inf

print("\n" + "═" * 70)
print("InceptionTime ENN + SMOTE summary")
print("═" * 70)

print(
    f"{'Dataset':<26} "
    f"{'Train N':>10} "
    f"{'Non-SEP':>8} "
    f"{'SEP':>8} "
    f"{'Ratio':>10} "
    f"{'Avg TSS':>10} "
    f"{'Avg F1':>10} "
    f"{'Avg Recall':>12}"
)

print("─" * 105)

for dataset_key, metrics_list in all_inception_smote_results.items():

    d = datasets_smote[dataset_key]

    counts = np.bincount(d["y_train"].astype(int), minlength=2)
    ratio = counts[0] / counts[1]

    avg_tss = np.mean([m["tss"] for m in metrics_list])
    avg_f1 = np.mean([m["f1"] for m in metrics_list])
    avg_recall = np.mean([m["recall"] for m in metrics_list])

    print(
        f"{dataset_key:<26} "
        f"{len(d['y_train']):>10} "
        f"{counts[0]:>8} "
        f"{counts[1]:>8} "
        f"{ratio:>9.1f}x "
        f"{avg_tss:>10.4f} "
        f"{avg_f1:>10.4f} "
        f"{avg_recall:>12.4f}"
    )

    if avg_tss > best_avg_tss:
        best_avg_tss = avg_tss
        best_dataset = dataset_key


print("\nBest InceptionTime ENN + SMOTE dataset:")
print(f"  Dataset : {best_dataset}")
print(f"  Avg TSS : {best_avg_tss:.4f}")
print(f"  Params  : {inception_label(best_params)}")

print("\n✅ All InceptionTime ENN + SMOTE experiments complete.")
print(f"Results saved to: {os.path.abspath(RESULTS_DIR)}/")
print(f"Files: {sorted([f for f in os.listdir(RESULTS_DIR) if f.endswith('.txt')])}")
# Out:
# ══════════════════════════════════════════════════════════════════════
#   Classifier : InceptionTime
#   Experiment : ENN + SMOTE / RUS + SMOTE
#   Best params: channels=16  depth=6  drop=0.3  lr=0.005  bs=128
# ══════════════════════════════════════════════════════════════════════
#
# ──────────────────────────────────────────────────────────────────────
# Dataset   : enn_smote_balanced
# Timesteps : 288
# Train     : (24300, 288, 10) | Non-SEP=12150 | SEP=12150
# Val       : (1780, 288, 10) | Non-SEP=1763 | SEP=17
# Test      : (3559, 288, 10) | Non-SEP=3525 | SEP=34
# Ratio     : 1.0:1
# Params    : channels=16  depth=6  drop=0.3  lr=0.005  bs=128
# ──────────────────────────────────────────────────────────────────────
# Run 1 …
# Run 1: TSS=0.0907 | F1=0.0313 | Recall=0.2059 | Train=181.2s
# Run 2 …
# Run 2: TSS=0.1100 | F1=0.0289 | Recall=0.2941 | Train=140.5s
#
# ───────────────────────────────────────────────────────
#   InceptionTime | enn_smote_balanced
# ───────────────────────────────────────────────────────
#   Run 1: TP=7  TN=3119  FP=406  FN=27
#          TSS=0.0907  HSS1=0.0139  HSS2=0.0139  GSS=0.0070
#          Recall=0.2059  F1=0.0313  Acc=0.8783
#          Train=181.20s  Infer=1.0532s
#
#   Run 2: TP=10  TN=2876  FP=649  FN=24
#          TSS=0.1100  HSS1=0.0109  HSS2=0.0109  GSS=0.0055
#          Recall=0.2941  F1=0.0289  Acc=0.8109
#          Train=140.53s  Infer=0.9688s
#
#   ── Average of 2 runs ──
#   tss          : 0.1004
#   hss1         : 0.0124
#   hss2         : 0.0124
#   gss          : 0.0062
#   recall       : 0.2500
#   f1           : 0.0301
#   accuracy     : 0.8446
#   train_time   : 160.8671
#   infer_time   : 1.0110
# ───────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────
# Dataset   : enn_rus8000_smote8000
# Timesteps : 288
# Train     : (16000, 288, 10) | Non-SEP=8000 | SEP=8000
# Val       : (1780, 288, 10) | Non-SEP=1763 | SEP=17
# Test      : (3559, 288, 10) | Non-SEP=3525 | SEP=34
# Ratio     : 1.0:1
# Params    : channels=16  depth=6  drop=0.3  lr=0.005  bs=128
# ──────────────────────────────────────────────────────────────────────
# Run 1 …
# Run 1: TSS=0.1365 | F1=0.0364 | Recall=0.2647 | Train=95.9s
# Run 2 …
# Run 2: TSS=0.2098 | F1=0.0493 | Recall=0.3235 | Train=111.4s
#
# ───────────────────────────────────────────────────────
#   InceptionTime | enn_rus8000_smote8000
# ───────────────────────────────────────────────────────
#   Run 1: TP=9  TN=3073  FP=452  FN=25
#          TSS=0.1365  HSS1=0.0189  HSS2=0.0189  GSS=0.0095
#          Recall=0.2647  F1=0.0364  Acc=0.8660
#          Train=95.88s  Infer=1.0314s
#
#   Run 2: TP=11  TN=3124  FP=401  FN=23
#          TSS=0.2098  HSS1=0.0322  HSS2=0.0322  GSS=0.0164
#          Recall=0.3235  F1=0.0493  Acc=0.8809
#          Train=111.38s  Infer=0.8908s
#
#   ── Average of 2 runs ──
#   tss          : 0.1731
#   hss1         : 0.0256
#   hss2         : 0.0256
#   gss          : 0.0130
#   recall       : 0.2941
#   f1           : 0.0428
#   accuracy     : 0.8734
#   train_time   : 103.6342
#   infer_time   : 0.9611
# ───────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────
# Dataset   : enn_rus4000_smote4000
# Timesteps : 288
# Train     : (8000, 288, 10) | Non-SEP=4000 | SEP=4000
# Val       : (1780, 288, 10) | Non-SEP=1763 | SEP=17
# Test      : (3559, 288, 10) | Non-SEP=3525 | SEP=34
# Ratio     : 1.0:1
# Params    : channels=16  depth=6  drop=0.3  lr=0.005  bs=128
# ──────────────────────────────────────────────────────────────────────
# Run 1 …
# Run 1: TSS=0.2011 | F1=0.0538 | Recall=0.2941 | Train=45.8s
# Run 2 …
# Run 2: TSS=0.1653 | F1=0.0402 | Recall=0.2941 | Train=45.5s
#
# ───────────────────────────────────────────────────────
#   InceptionTime | enn_rus4000_smote4000
# ───────────────────────────────────────────────────────
#   Run 1: TP=10  TN=3197  FP=328  FN=24
#          TSS=0.2011  HSS1=0.0370  HSS2=0.0370  GSS=0.0189
#          Recall=0.2941  F1=0.0538  Acc=0.9011
#          Train=45.84s  Infer=0.7999s
#
#   Run 2: TP=10  TN=3071  FP=454  FN=24
#          TSS=0.1653  HSS1=0.0228  HSS2=0.0228  GSS=0.0115
#          Recall=0.2941  F1=0.0402  Acc=0.8657
#          Train=45.53s  Infer=0.7503s
#
#   ── Average of 2 runs ──
#   tss          : 0.1832
#   hss1         : 0.0299
#   hss2         : 0.0299
#   gss          : 0.0152
#   recall       : 0.2941
#   f1           : 0.0470
#   accuracy     : 0.8834
#   train_time   : 45.6814
#   infer_time   : 0.7751
# ───────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────
# Dataset   : enn_rus2000_smote2000
# Timesteps : 288
# Train     : (4000, 288, 10) | Non-SEP=2000 | SEP=2000
# Val       : (1780, 288, 10) | Non-SEP=1763 | SEP=17
# Test      : (3559, 288, 10) | Non-SEP=3525 | SEP=34
# Ratio     : 1.0:1
# Params    : channels=16  depth=6  drop=0.3  lr=0.005  bs=128
# ──────────────────────────────────────────────────────────────────────
# Run 1 …
# Run 1: TSS=0.1644 | F1=0.0548 | Recall=0.2353 | Train=23.9s
# Run 2 …
# Run 2: TSS=0.1588 | F1=0.0676 | Recall=0.2059 | Train=24.3s
#
# ───────────────────────────────────────────────────────
#   InceptionTime | enn_rus2000_smote2000
# ───────────────────────────────────────────────────────
#   Run 1: TP=8  TN=3275  FP=250  FN=26
#          TSS=0.1644  HSS1=0.0386  HSS2=0.0386  GSS=0.0197
#          Recall=0.2353  F1=0.0548  Acc=0.9225
#          Train=23.94s  Infer=0.9087s
#
#   Run 2: TP=7  TN=3359  FP=166  FN=27
#          TSS=0.1588  HSS1=0.0525  HSS2=0.0525  GSS=0.0270
#          Recall=0.2059  F1=0.0676  Acc=0.9458
#          Train=24.35s  Infer=0.8428s
#
#   ── Average of 2 runs ──
#   tss          : 0.1616
#   hss1         : 0.0455
#   hss2         : 0.0455
#   gss          : 0.0233
#   recall       : 0.2206
#   f1           : 0.0612
#   accuracy     : 0.9341
#   train_time   : 24.1422
#   infer_time   : 0.8757
# ───────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────
# Dataset   : enn_rus1000_smote1000
# Timesteps : 288
# Train     : (2000, 288, 10) | Non-SEP=1000 | SEP=1000
# Val       : (1780, 288, 10) | Non-SEP=1763 | SEP=17
# Test      : (3559, 288, 10) | Non-SEP=3525 | SEP=34
# Ratio     : 1.0:1
# Params    : channels=16  depth=6  drop=0.3  lr=0.005  bs=128
# ──────────────────────────────────────────────────────────────────────
# Run 1 …
# Run 1: TSS=0.0712 | F1=0.0619 | Recall=0.0882 | Train=13.3s
# Run 2 …
# Run 2: TSS=0.1322 | F1=0.0612 | Recall=0.1765 | Train=13.2s
#
# ───────────────────────────────────────────────────────
#   InceptionTime | enn_rus1000_smote1000
# ───────────────────────────────────────────────────────
#   Run 1: TP=3  TN=3465  FP=60  FN=31
#          TSS=0.0712  HSS1=0.0501  HSS2=0.0501  GSS=0.0257
#          Recall=0.0882  F1=0.0619  Acc=0.9744
#          Train=13.31s  Infer=0.7768s
#
#   Run 2: TP=6  TN=3369  FP=156  FN=28
#          TSS=0.1322  HSS1=0.0462  HSS2=0.0462  GSS=0.0236
#          Recall=0.1765  F1=0.0612  Acc=0.9483
#          Train=13.20s  Infer=0.7392s
#
#   ── Average of 2 runs ──
#   tss          : 0.1017
#   hss1         : 0.0481
#   hss2         : 0.0481
#   gss          : 0.0247
#   recall       : 0.1324
#   f1           : 0.0615
#   accuracy     : 0.9614
#   train_time   : 13.2581
#   infer_time   : 0.7580
# ───────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────
# Dataset   : enn_rus500_smote500
# Timesteps : 288
# Train     : (1000, 288, 10) | Non-SEP=500 | SEP=500
# Val       : (1780, 288, 10) | Non-SEP=1763 | SEP=17
# Test      : (3559, 288, 10) | Non-SEP=3525 | SEP=34
# Ratio     : 1.0:1
# Params    : channels=16  depth=6  drop=0.3  lr=0.005  bs=128
# ──────────────────────────────────────────────────────────────────────
# Run 1 …
# Run 1: TSS=0.2574 | F1=0.0791 | Recall=0.3235 | Train=13.6s
# Run 2 …
# Run 2: TSS=0.0279 | F1=0.0276 | Recall=0.0588 | Train=10.6s
#
# ───────────────────────────────────────────────────────
#   InceptionTime | enn_rus500_smote500
# ───────────────────────────────────────────────────────
#   Run 1: TP=11  TN=3292  FP=233  FN=23
#          TSS=0.2574  HSS1=0.0634  HSS2=0.0634  GSS=0.0328
#          Recall=0.3235  F1=0.0791  Acc=0.9281
#          Train=13.57s  Infer=0.8996s
#
#   Run 2: TP=2  TN=3416  FP=109  FN=32
#          TSS=0.0279  HSS1=0.0132  HSS2=0.0132  GSS=0.0066
#          Recall=0.0588  F1=0.0276  Acc=0.9604
#          Train=10.57s  Infer=0.7956s
#
#   ── Average of 2 runs ──
#   tss          : 0.1427
#   hss1         : 0.0383
#   hss2         : 0.0383
#   gss          : 0.0197
#   recall       : 0.1912
#   f1           : 0.0534
#   accuracy     : 0.9442
#   train_time   : 12.0712
#   infer_time   : 0.8476
# ───────────────────────────────────────────────────────
#
# ══════════════════════════════════════════════════════════════════════
# InceptionTime ENN + SMOTE summary
# ══════════════════════════════════════════════════════════════════════
# Dataset                       Train N  Non-SEP      SEP      Ratio    Avg TSS     Avg F1   Avg Recall
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────
# enn_smote_balanced              24300    12150    12150       1.0x     0.1004     0.0301       0.2500
# enn_rus8000_smote8000           16000     8000     8000       1.0x     0.1731     0.0428       0.2941
# enn_rus4000_smote4000            8000     4000     4000       1.0x     0.1832     0.0470       0.2941
# enn_rus2000_smote2000            4000     2000     2000       1.0x     0.1616     0.0612       0.2206
# enn_rus1000_smote1000            2000     1000     1000       1.0x     0.1017     0.0615       0.1324
# enn_rus500_smote500              1000      500      500       1.0x     0.1427     0.0534       0.1912
#
# Best InceptionTime ENN + SMOTE dataset:
#   Dataset : enn_rus4000_smote4000
#   Avg TSS : 0.1832
#   Params  : channels=16  depth=6  drop=0.3  lr=0.005  bs=128
#
# ✅ All InceptionTime ENN + SMOTE experiments complete.
# Results saved to: /Users/samskanderi/SEP_DataAugmentation/results/
# Files: ['gru_enn_nonsep_1000.txt', 'gru_enn_nonsep_2000.txt', 'gru_enn_nonsep_4000.txt', 'gru_enn_nonsep_500.txt', 'gru_enn_nonsep_8000.txt', 'gru_enn_rus1000_smote1000.txt', 'gru_enn_rus2000_smote2000.txt', 'gru_enn_rus4000_smote4000.txt', 'gru_enn_rus500_smote500.txt', 'gru_enn_rus8000_smote8000.txt', 'gru_enn_smote_balanced.txt', 'gru_hybrid.txt', 'gru_hybrid_12h.txt', 'gru_hybrid_18h.txt', 'gru_hybrid_6h.txt', 'gru_hybrid_9h.txt', 'gru_hybrid_enn.txt', 'gru_hybrid_nearmiss.txt', 'gru_hybrid_tomek.txt', 'gru_log_all.txt', 'gru_minmax_all.txt', 'gru_zscore_all.txt', 'inceptiontime_enn_nonsep_1000.txt', 'inceptiontime_enn_nonsep_2000.txt', 'inceptiontime_enn_nonsep_4000.txt', 'inceptiontime_enn_nonsep_500.txt', 'inceptiontime_enn_nonsep_8000.txt', 'inceptiontime_enn_rus1000_smote1000.txt', 'inceptiontime_enn_rus2000_smote2000.txt', 'inceptiontime_enn_rus4000_smote4000.txt', 'inceptiontime_enn_rus500_smote500.txt', 'inceptiontime_enn_rus8000_smote8000.txt', 'inceptiontime_enn_smote_balanced.txt', 'inceptiontime_hybrid.txt', 'inceptiontime_hybrid_12h.txt', 'inceptiontime_hybrid_18h.txt', 'inceptiontime_hybrid_6h.txt', 'inceptiontime_hybrid_9h.txt', 'inceptiontime_hybrid_enn.txt', 'inceptiontime_hybrid_nearmiss.txt', 'inceptiontime_hybrid_tomek.txt', 'inceptiontime_log_all.txt', 'inceptiontime_minmax_all.txt', 'inceptiontime_zscore_all.txt', 'patchtst_enn_nonsep_1000.txt', 'patchtst_enn_nonsep_2000.txt', 'patchtst_enn_nonsep_4000.txt', 'patchtst_enn_nonsep_500.txt', 'patchtst_enn_nonsep_8000.txt', 'patchtst_enn_rus1000_smote1000.txt', 'patchtst_enn_rus2000_smote2000.txt', 'patchtst_enn_rus4000_smote4000.txt', 'patchtst_enn_rus500_smote500.txt', 'patchtst_enn_rus8000_smote8000.txt', 'patchtst_enn_smote_balanced.txt', 'patchtst_hybrid.txt', 'patchtst_hybrid_12h.txt', 'patchtst_hybrid_18h.txt', 'patchtst_hybrid_6h.txt', 'patchtst_hybrid_9h.txt', 'patchtst_hybrid_enn.txt', 'patchtst_hybrid_nearmiss.txt', 'patchtst_hybrid_tomek.txt', 'patchtst_log_all.txt', 'patchtst_minmax_all.txt', 'patchtst_zscore_all.txt', 'svm_enn_nonsep_1000.txt', 'svm_enn_nonsep_2000.txt', 'svm_enn_nonsep_4000.txt', 'svm_enn_nonsep_500.txt', 'svm_enn_nonsep_8000.txt', 'svm_enn_rus1000_smote1000.txt', 'svm_enn_rus2000_smote2000.txt', 'svm_enn_rus4000_smote4000.txt', 'svm_enn_rus500_smote500.txt', 'svm_enn_rus8000_smote8000.txt', 'svm_enn_smote_balanced.txt', 'svm_hybrid.txt', 'svm_hybrid_12h.txt', 'svm_hybrid_18h.txt', 'svm_hybrid_6h.txt', 'svm_hybrid_9h.txt', 'svm_log_all.txt', 'svm_minmax_all.txt', 'svm_zscore_all.txt']
